# %% [markdown]
# #### CSC 296S Deep Learning (Spring 2026)
#
# #### Dr. Haiquan Chen, Dept of Computer Scicence
#
# #### California State University, Sacramento

# %% [markdown]
# ## Lab 5: Hyper-parameter Tuning and Dropout

# %% [markdown]
# ### Helpful Functions for Tensorflow (Little Gems)
#
# The following functions will be used with TensorFlow to help preprocess the data.  They allow you to build the feature vector for a neural network.
#
# * Predictors/Inputs
#     * Fill any missing inputs with the median for that column.  Use **missing_median**.
#     * Encode textual/categorical values with **encode_text_dummy**.
#     * Encode numeric values with **encode_numeric_zscore**.
# * Output
#     * Discard rows with missing outputs.
#     * Encode textual/categorical values with **encode_text_index**.
#     * Do not encode output numeric values.
# * Produce final feature vectors (x) and expected output (y) with **to_xy**.

# %%
from collections.abc import Sequence
from sklearn import preprocessing
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


# Encode text values to dummy variables(i.e. [1,0,0],[0,1,0],[0,0,1] for red,green,blue)
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    for x in dummies.columns:
        dummy_name = "{}-{}".format(name, x)
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)


# Encode text values to indexes(i.e. [1],[2],[3] for red,green,blue).
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    df[name] = le.fit_transform(df[name])
    return le.classes_


# Encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    if mean is None:
        mean = df[name].mean()

    if sd is None:
        sd = df[name].std()

    df[name] = (df[name] - mean) / sd


# Convert all missing values in the specified column to the median
def missing_median(df, name):
    med = df[name].median()
    df[name] = df[name].fillna(med)


# Convert all missing values in the specified column to the default
def missing_default(df, name, default_value):
    df[name] = df[name].fillna(default_value)


# Convert a Pandas dataframe to the x,y inputs that TensorFlow needs
def to_xy(df, target):
    result = []
    for x in df.columns:
        if x != target:
            result.append(x)
    # find out the type of the target column. 
    target_type = df[target].dtypes
    target_type = target_type[0] if isinstance(target_type, Sequence) else target_type
    # Encode to int for classification, float otherwise. TensorFlow likes 32 bits.
    if target_type in (np.int64, np.int32):
        # Classification
        dummies = pd.get_dummies(df[target])
        return df[result].values.astype(np.float32), dummies.values.astype(np.float32)
    else:
        # Regression
        return df[result].values.astype(np.float32), df[target].values.astype(np.float32)

# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)


# Regression chart.
def chart_regression(pred,y,sort=True):
    t = pd.DataFrame({'pred' : pred, 'y' : y.flatten()})
    if sort:
        t.sort_values(by=['y'],inplace=True)
    a = plt.plot(t['y'].tolist(),label='expected')
    b = plt.plot(t['pred'].tolist(),label='prediction')
    plt.ylabel('output')
    plt.legend()
    plt.show()

# Remove all rows where the specified column is +/- sd standard deviations
def remove_outliers(df, name, sd):
    drop_rows = df.index[(np.abs(df[name] - df[name].mean()) >= (sd * df[name].std()))]
    df.drop(drop_rows, axis=0, inplace=True)


# Encode a column to a range between normalized_low and normalized_high.
def encode_numeric_range(df, name, normalized_low=-1, normalized_high=1,
                         data_low=None, data_high=None):
    if data_low is None:
        data_low = min(df[name])
        data_high = max(df[name])

    df[name] = ((df[name] - data_low) / (data_high - data_low)) \
               * (normalized_high - normalized_low) + normalized_low

# %% [markdown]
# ## "Hyper"-parameters vs "regular" parameters
#
# "Hyperparameters" are not changed when the neural network trains. They are design choices. You, the network designer, must define the "hyperparameters".
#
# Neural network weights learned from data are known as "regular" parameter. The neural network learns "regular" parameters during neural network training.

# %% [markdown]
# ### Layer type, Number of Hidden Layers, and Neuron Counts
#
# How many layers should you have? How many neurons are on each layer? What activation function and layer type should you use? Generally, the number of neurons on each layer will gradually decrease as you traverse the model from input to output. This configuration gives the neural network a somewhat triangular or trapezoid.
#
# There are many different [types of layer](https://keras.io/layers/core/) in Keras, listed here:
#
# * **Activation** - You can also add activation functions as layers.  Using the activation layer is the same as specifying the activation function as part of a Dense (or other) layer type.
# * **Dense** - The original neural network layer type. In this layer type, every neuron connects to the next layer. The input vector is one-dimensional, and placing specific inputs next does not affect each other.
# * **Dropout** - Dropout consists of randomly setting a fraction rate of input units to 0 at each update during training time, which helps prevent overfitting. Dropout only occurs during training.
# * **Flatten** - Flattens the input to 1D and does not affect the batch size.
# * **Input** - A Keras tensor is a tensor object from the underlying back end (Theano, TensorFlow, or CNTK), which we augment with specific attributes to build a Keras by knowing the inputs and outputs of the model.
# * **Lambda** - Wraps arbitrary expression as a Layer object.
# * **Masking** - Masks a sequence using a mask value to skip timesteps.
# * **Permute** - Permutes the input dimensions according to a given pattern. Useful for tasks such as connecting RNNs and convolutional networks.
# * **RepeatVector** - Repeats the input n times.
# * **Reshape** - Similar to Numpy reshapes.

# %% [markdown]
# ### Activation Functions
#
# Activation functions are a choice that you must make for each layer. Generally, you can follow this guideline:
# * Hidden Layers - RELU
# * Output Layer - Softmax for classification, No activation for regression.
#
# Some of the common activation functions in Keras are listed here:
#
# * **softmax** - Used for multi-class classification.  Ensures all output neurons behave as probabilities and sum to 1.0.
# * **elu** - Exponential linear unit.  Exponential Linear Unit or its widely known name ELU is a function that tends to converge cost to zero faster and produce more accurate results. Can produce negative outputs.
# * **selu** - Scaled Exponential Linear Unit (SELU), essentially **elu** multiplied by a scaling constant.
# * **softplus** - Softplus activation function. $log(exp(x) + 1)$
# * **softsign** Softsign activation function. $x / (abs(x) + 1)$ Similar to tanh, but not widely used.
# * **relu** - Very popular neural network activation function.  Used for hidden layers, cannot output negative values. No trainable parameters.
# * **tanh** Classic neural network activation function, though often replaced by relu family on modern networks.
# * **sigmoid** - Classic neural network activation.  Often used on output layer of a binary classifier.
# * **hard_sigmoid** - Less computationally expensive variant of sigmoid.
# * **exponential** - Exponential (base e) activation function.
# * **linear** - Pass-through activation function. Also known as "no activation," or "identity function" (multiplied x1. 0).
#
# For more information about Keras activation functions refer to the following:
#
# * [Keras Activation Functions](https://keras.io/activations/)
# * [Activation Function Cheat Sheets](https://ml-cheatsheet.readthedocs.io/en/latest/activation_functions.html)
#
#
# ### Regularization: L1, L2, Dropout
#
# Regularizers allow you to apply penalties on layer parameters or layer activity during optimization. They are used to mitigate overfiltting.
#
# * [Keras Regularization](https://keras.io/regularizers/)
# * [Keras Dropout](https://keras.io/layers/core/)
#
# ### Batch and Layer Normalization
#
# * [Keras Batch Normalization](https://keras.io/layers/normalization/)
#
# Batch and layer normalization are two strategies for training neural networks faster and stable.
# * BatchNorm normalizes each feature ```within a batch of samples``` into the same range,
# * LayerNorm normalizes ```all features``` within each sample into the same range.

# %% [markdown]
# ### Learning rate
# Backpropagation is the primary means by which a neural network's weights are determined during training. Backpropagation works by calculating a weight change amount ($v_t$) for every weight($\theta$, theata) in the neural network.  This value is subtracted from every weight by the following equation:
#
# $ \theta_t = \theta_{t-1} - v_t $
#
#
# * Too low of a learning rate will usually converge to a good solution; however, the process will be very slow.
# * Too high of a learning rate will either fail outright, causing loss occilating, or converge to a higher error.
#
# Common values for learning rate are: 0.1, 0.01, 0.001, etc.

# %% [markdown]
# ### Batch size
#
# Number of samples per gradient update.  In keras, you may set the batch_size parameter in function fit()
#
# batch_size: Integer or None. Number of samples per gradient update. If unspecified, batch_size will default to 32.

# %% [markdown]
# ### Optimizer (the paramter update rule)
#
# https://keras.io/optimizers/
#
# ```An optimizer is one of the two arguments required when you compile a Keras model using compile().```
#
# ```What is the other argument required using compile()? ```
#
# TensorFlow allows the update rule to be set to one of:
#
# * Adagrad
# * **Adam**
# * Ftrl
# * Momentum
# * RMSProp
# * **SGD**

# %% [markdown]
# You can either instantiate an optimizer or you can call it by its name. In the latter case, the default parameters for the optimizer will be used.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Activation

model = Sequential()
model.add(Dense(10, input_dim=10, activation='relu'))
model.add(Dense(1))

sgd = optimizers.SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)

#adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='mean_squared_error', optimizer=sgd)

# %% [markdown]
# or using all Default Parameters for a Particular Optimizer

# %%
# pass optimizer by name: default parameters will be used
model.compile(loss='mean_squared_error', optimizer='sgd')

# %% [markdown]
# ## A Complete Example:

# %%
# %matplotlib inline
from matplotlib.pyplot import figure, show
from sklearn.model_selection import train_test_split
import pandas as pd
import os
import numpy as np
from sklearn import metrics

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import optimizers

path = "./data/"
preprocess = True

filename_read = os.path.join(path,"auto-mpg.csv")
df = pd.read_csv(filename_read,na_values=['NA','?'])

# create feature vector
missing_median(df, 'horsepower')
encode_text_dummy(df, 'origin')
df.drop('name',axis=1,inplace=True)
if preprocess:
    encode_numeric_zscore(df, 'horsepower')
    encode_numeric_zscore(df, 'weight')
    encode_numeric_zscore(df, 'cylinders')
    encode_numeric_zscore(df, 'displacement')
    encode_numeric_zscore(df, 'acceleration')
    encode_numeric_zscore(df, 'year')

# Encode to a 2D matrix for training
x,y = to_xy(df,'mpg')

# Split into train/test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)

model = Sequential()
model.add(Dense(10, input_dim=x.shape[1], activation='relu'))
 
model.add(Dense(1, activation='relu'))

adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='mean_squared_error', optimizer=adam)

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
checkpointer = ModelCheckpoint(filepath="dnn/best_weights.keras", verbose=0, save_best_only=True) # save best model

# batch_size: Integer or None. Number of samples per gradient update. If unspecified, batch_size will default to 32.
model.fit(x_train,y_train,validation_data=(x_test,y_test), batch_size= 128, callbacks=[monitor,checkpointer],verbose=2,epochs=1000)
model.load_weights('dnn/best_weights.keras') # load weights from best model
# Predict and measure RMSE
pred = model.predict(x_test)
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Score (RMSE): {}".format(score))

# Plot the chart
chart_regression(pred.flatten(),y_test)
# Out:
# Epoch 1/1000
# c:\ProgramData\Anaconda3\envs\tf-gpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 3/3 - 2s - loss: 616.3516 - val_loss: 584.3538 - 2s/epoch - 624ms/step
# Epoch 2/1000
# 3/3 - 0s - loss: 615.9182 - val_loss: 583.9205 - 74ms/epoch - 25ms/step
# Epoch 3/1000
# 3/3 - 0s - loss: 615.4504 - val_loss: 583.4834 - 62ms/epoch - 21ms/step
# Epoch 4/1000
# 3/3 - 0s - loss: 614.9217 - val_loss: 582.9496 - 52ms/epoch - 17ms/step
# Epoch 5/1000
# 3/3 - 0s - loss: 614.3719 - val_loss: 582.3174 - 56ms/epoch - 19ms/step
# Epoch 6/1000
# 3/3 - 0s - loss: 613.7914 - val_loss: 581.6664 - 77ms/epoch - 26ms/step
# Epoch 7/1000
# 3/3 - 0s - loss: 613.1555 - val_loss: 580.9923 - 54ms/epoch - 18ms/step
# Epoch 8/1000
# 3/3 - 0s - loss: 612.4381 - val_loss: 580.2857 - 58ms/epoch - 19ms/step
# Epoch 9/1000
# 3/3 - 0s - loss: 611.7034 - val_loss: 579.5236 - 58ms/epoch - 19ms/step
# Epoch 10/1000
# 3/3 - 0s - loss: 610.8480 - val_loss: 578.7297 - 56ms/epoch - 19ms/step
# Epoch 11/1000
# 3/3 - 0s - loss: 609.9830 - val_loss: 577.9269 - 54ms/epoch - 18ms/step
# Epoch 12/1000
# 3/3 - 0s - loss: 609.0652 - val_loss: 577.1088 - 63ms/epoch - 21ms/step
# Epoch 13/1000
# 3/3 - 0s - loss: 608.1193 - val_loss: 576.2606 - 60ms/epoch - 20ms/step
# Epoch 14/1000
# 3/3 - 0s - loss: 607.1311 - val_loss: 575.3720 - 51ms/epoch - 17ms/step
# Epoch 15/1000
# 3/3 - 0s - loss: 606.0956 - val_loss: 574.4411 - 53ms/epoch - 18ms/step
# Epoch 16/1000
# 3/3 - 0s - loss: 604.9986 - val_loss: 573.4927 - 63ms/epoch - 21ms/step
# Epoch 17/1000
# 3/3 - 0s - loss: 603.8050 - val_loss: 572.4830 - 67ms/epoch - 22ms/step
# Epoch 18/1000
# 3/3 - 0s - loss: 602.6256 - val_loss: 571.4386 - 64ms/epoch - 21ms/step
# Epoch 19/1000
# 3/3 - 0s - loss: 601.4197 - val_loss: 570.3742 - 64ms/epoch - 21ms/step
# Epoch 20/1000
# 3/3 - 0s - loss: 600.0775 - val_loss: 569.2992 - 64ms/epoch - 21ms/step
# Epoch 21/1000
# 3/3 - 0s - loss: 598.7494 - val_loss: 568.1986 - 63ms/epoch - 21ms/step
# Epoch 22/1000
# 3/3 - 0s - loss: 597.3536 - val_loss: 567.0649 - 58ms/epoch - 19ms/step
# Epoch 23/1000
# 3/3 - 0s - loss: 595.9129 - val_loss: 565.8611 - 59ms/epoch - 20ms/step
# Epoch 24/1000
# 3/3 - 0s - loss: 594.3784 - val_loss: 564.6313 - 66ms/epoch - 22ms/step
# Epoch 25/1000
# 3/3 - 0s - loss: 592.7859 - val_loss: 563.3613 - 58ms/epoch - 19ms/step
# Epoch 26/1000
# 3/3 - 0s - loss: 591.2219 - val_loss: 561.9813 - 66ms/epoch - 22ms/step
# Epoch 27/1000
# 3/3 - 0s - loss: 589.5795 - val_loss: 560.5153 - 49ms/epoch - 16ms/step
# Epoch 28/1000
# 3/3 - 0s - loss: 587.8784 - val_loss: 558.9879 - 50ms/epoch - 17ms/step
# Epoch 29/1000
# 3/3 - 0s - loss: 586.0984 - val_loss: 557.4324 - 57ms/epoch - 19ms/step
# Epoch 30/1000
# 3/3 - 0s - loss: 584.2488 - val_loss: 555.8324 - 76ms/epoch - 25ms/step
# Epoch 31/1000
# 3/3 - 0s - loss: 582.3966 - val_loss: 554.1792 - 69ms/epoch - 23ms/step
# Epoch 32/1000
# 3/3 - 0s - loss: 580.4352 - val_loss: 552.4998 - 77ms/epoch - 26ms/step
# Epoch 33/1000
# 3/3 - 0s - loss: 578.4169 - val_loss: 550.7762 - 69ms/epoch - 23ms/step
# Epoch 34/1000
# 3/3 - 0s - loss: 576.4032 - val_loss: 548.9829 - 125ms/epoch - 42ms/step
# Epoch 35/1000
# 3/3 - 0s - loss: 574.3246 - val_loss: 547.1206 - 75ms/epoch - 25ms/step
# Epoch 36/1000
# 3/3 - 0s - loss: 572.1285 - val_loss: 545.2142 - 67ms/epoch - 22ms/step
# Epoch 37/1000
# 3/3 - 0s - loss: 569.9739 - val_loss: 543.2338 - 72ms/epoch - 24ms/step
# Epoch 38/1000
# 3/3 - 0s - loss: 567.7686 - val_loss: 541.2192 - 74ms/epoch - 25ms/step
# Epoch 39/1000
# 3/3 - 0s - loss: 565.4591 - val_loss: 539.1963 - 77ms/epoch - 26ms/step
# Epoch 40/1000
# 3/3 - 0s - loss: 563.1642 - val_loss: 537.1313 - 71ms/epoch - 24ms/step
# Epoch 41/1000
# 3/3 - 0s - loss: 560.8079 - val_loss: 535.0143 - 66ms/epoch - 22ms/step
# Epoch 42/1000
# 3/3 - 0s - loss: 558.3671 - val_loss: 532.8607 - 78ms/epoch - 26ms/step
# Epoch 43/1000
# 3/3 - 0s - loss: 555.8664 - val_loss: 530.6632 - 66ms/epoch - 22ms/step
# Epoch 44/1000
# 3/3 - 0s - loss: 553.4208 - val_loss: 528.4105 - 61ms/epoch - 20ms/step
# Epoch 45/1000
# 3/3 - 0s - loss: 550.8436 - val_loss: 526.1215 - 53ms/epoch - 18ms/step
# Epoch 46/1000
# 3/3 - 0s - loss: 548.1825 - val_loss: 523.8067 - 61ms/epoch - 20ms/step
# Epoch 47/1000
# 3/3 - 0s - loss: 545.5132 - val_loss: 521.4191 - 68ms/epoch - 23ms/step
# Epoch 48/1000
# 3/3 - 0s - loss: 542.8479 - val_loss: 518.9997 - 75ms/epoch - 25ms/step
# Epoch 49/1000
# 3/3 - 0s - loss: 540.1119 - val_loss: 516.5084 - 70ms/epoch - 23ms/step
# Epoch 50/1000
# 3/3 - 0s - loss: 537.3491 - val_loss: 513.9932 - 79ms/epoch - 26ms/step
# Epoch 51/1000
# 3/3 - 0s - loss: 534.5064 - val_loss: 511.4544 - 63ms/epoch - 21ms/step
# Epoch 52/1000
# 3/3 - 0s - loss: 531.6216 - val_loss: 508.8459 - 65ms/epoch - 22ms/step
# Epoch 53/1000
# 3/3 - 0s - loss: 528.7385 - val_loss: 506.2042 - 67ms/epoch - 22ms/step
# Epoch 54/1000
# 3/3 - 0s - loss: 525.8544 - val_loss: 503.5075 - 63ms/epoch - 21ms/step
# Epoch 55/1000
# 3/3 - 0s - loss: 522.8816 - val_loss: 500.7880 - 54ms/epoch - 18ms/step
# Epoch 56/1000
# 3/3 - 0s - loss: 519.9172 - val_loss: 498.0213 - 74ms/epoch - 25ms/step
# Epoch 57/1000
# 3/3 - 0s - loss: 516.9604 - val_loss: 495.2386 - 77ms/epoch - 26ms/step
# Epoch 58/1000
# 3/3 - 0s - loss: 513.8674 - val_loss: 492.4598 - 67ms/epoch - 22ms/step
# Epoch 59/1000
# 3/3 - 0s - loss: 510.7937 - val_loss: 489.6585 - 60ms/epoch - 20ms/step
# Epoch 60/1000
# 3/3 - 0s - loss: 507.7551 - val_loss: 486.8094 - 67ms/epoch - 22ms/step
# Epoch 61/1000
# 3/3 - 0s - loss: 504.6659 - val_loss: 483.9308 - 69ms/epoch - 23ms/step
# Epoch 62/1000
# 3/3 - 0s - loss: 501.5457 - val_loss: 481.0363 - 65ms/epoch - 22ms/step
# Epoch 63/1000
# 3/3 - 0s - loss: 498.4167 - val_loss: 478.0777 - 56ms/epoch - 19ms/step
# Epoch 64/1000
# 3/3 - 0s - loss: 495.1886 - val_loss: 475.0919 - 74ms/epoch - 25ms/step
# Epoch 65/1000
# 3/3 - 0s - loss: 491.9814 - val_loss: 472.0468 - 58ms/epoch - 19ms/step
# Epoch 66/1000
# 3/3 - 0s - loss: 488.7095 - val_loss: 468.9801 - 50ms/epoch - 17ms/step
# Epoch 67/1000
# 3/3 - 0s - loss: 485.4543 - val_loss: 465.8847 - 59ms/epoch - 20ms/step
# Epoch 68/1000
# 3/3 - 0s - loss: 482.0659 - val_loss: 462.7846 - 57ms/epoch - 19ms/step
# Epoch 69/1000
# 3/3 - 0s - loss: 478.7242 - val_loss: 459.6485 - 74ms/epoch - 25ms/step
# Epoch 70/1000
# 3/3 - 0s - loss: 475.4239 - val_loss: 456.4810 - 60ms/epoch - 20ms/step
# Epoch 71/1000
# 3/3 - 0s - loss: 472.0001 - val_loss: 453.3087 - 58ms/epoch - 19ms/step
# Epoch 72/1000
# 3/3 - 0s - loss: 468.6003 - val_loss: 450.0982 - 57ms/epoch - 19ms/step
# Epoch 73/1000
# 3/3 - 0s - loss: 465.2321 - val_loss: 446.8760 - 72ms/epoch - 24ms/step
# Epoch 74/1000
# 3/3 - 0s - loss: 461.7276 - val_loss: 443.6369 - 70ms/epoch - 23ms/step
# Epoch 75/1000
# 3/3 - 0s - loss: 458.2853 - val_loss: 440.3860 - 66ms/epoch - 22ms/step
# Epoch 76/1000
# 3/3 - 0s - loss: 454.7742 - val_loss: 437.1089 - 64ms/epoch - 21ms/step
# Epoch 77/1000
# 3/3 - 0s - loss: 451.2122 - val_loss: 433.7845 - 68ms/epoch - 23ms/step
# Epoch 78/1000
# 3/3 - 0s - loss: 447.8297 - val_loss: 430.4360 - 53ms/epoch - 18ms/step
# Epoch 79/1000
# 3/3 - 0s - loss: 444.1536 - val_loss: 427.0935 - 72ms/epoch - 24ms/step
# Epoch 80/1000
# 3/3 - 0s - loss: 440.6092 - val_loss: 423.7230 - 52ms/epoch - 17ms/step
# Epoch 81/1000
# 3/3 - 0s - loss: 437.0597 - val_loss: 420.3557 - 72ms/epoch - 24ms/step
# Epoch 82/1000
# 3/3 - 0s - loss: 433.5017 - val_loss: 416.9749 - 67ms/epoch - 22ms/step
# Epoch 83/1000
# 3/3 - 0s - loss: 429.8879 - val_loss: 413.5890 - 62ms/epoch - 21ms/step
# Epoch 84/1000
# 3/3 - 0s - loss: 426.3172 - val_loss: 410.1957 - 55ms/epoch - 18ms/step
# Epoch 85/1000
# 3/3 - 0s - loss: 422.6732 - val_loss: 406.7962 - 55ms/epoch - 18ms/step
# Epoch 86/1000
# 3/3 - 0s - loss: 419.1298 - val_loss: 403.3626 - 58ms/epoch - 19ms/step
# Epoch 87/1000
# 3/3 - 0s - loss: 415.4690 - val_loss: 399.9293 - 66ms/epoch - 22ms/step
# Epoch 88/1000
# 3/3 - 0s - loss: 411.7914 - val_loss: 396.5181 - 99ms/epoch - 33ms/step
# Epoch 89/1000
# 3/3 - 0s - loss: 408.1652 - val_loss: 393.0850 - 52ms/epoch - 17ms/step
# Epoch 90/1000
# 3/3 - 0s - loss: 404.5555 - val_loss: 389.6353 - 70ms/epoch - 23ms/step
# Epoch 91/1000
# 3/3 - 0s - loss: 400.8664 - val_loss: 386.1879 - 55ms/epoch - 18ms/step
# Epoch 92/1000
# 3/3 - 0s - loss: 397.1936 - val_loss: 382.7001 - 58ms/epoch - 19ms/step
# Epoch 93/1000
# 3/3 - 0s - loss: 393.5171 - val_loss: 379.1811 - 58ms/epoch - 19ms/step
# Epoch 94/1000
# 3/3 - 0s - loss: 389.8330 - val_loss: 375.6517 - 59ms/epoch - 20ms/step
# Epoch 95/1000
# 3/3 - 0s - loss: 386.0796 - val_loss: 372.1366 - 54ms/epoch - 18ms/step
# Epoch 96/1000
# 3/3 - 0s - loss: 382.3010 - val_loss: 368.6255 - 64ms/epoch - 21ms/step
# Epoch 97/1000
# 3/3 - 0s - loss: 378.6474 - val_loss: 365.0471 - 61ms/epoch - 20ms/step
# Epoch 98/1000
# 3/3 - 0s - loss: 374.9204 - val_loss: 361.4828 - 63ms/epoch - 21ms/step
# Epoch 99/1000
# 3/3 - 0s - loss: 371.1295 - val_loss: 357.8853 - 58ms/epoch - 19ms/step
# Epoch 100/1000
# 3/3 - 0s - loss: 367.3633 - val_loss: 354.2814 - 76ms/epoch - 25ms/step
# Epoch 101/1000
# 3/3 - 0s - loss: 363.6684 - val_loss: 350.6547 - 55ms/epoch - 18ms/step
# Epoch 102/1000
# 3/3 - 0s - loss: 359.8294 - val_loss: 347.0511 - 59ms/epoch - 20ms/step
# Epoch 103/1000
# 3/3 - 0s - loss: 356.0365 - val_loss: 343.4343 - 57ms/epoch - 19ms/step
# Epoch 104/1000
# 3/3 - 0s - loss: 352.2151 - val_loss: 339.8331 - 52ms/epoch - 17ms/step
# Epoch 105/1000
# 3/3 - 0s - loss: 348.4229 - val_loss: 336.2160 - 51ms/epoch - 17ms/step
# Epoch 106/1000
# 3/3 - 0s - loss: 344.5500 - val_loss: 332.6082 - 61ms/epoch - 20ms/step
# Epoch 107/1000
# 3/3 - 0s - loss: 340.7704 - val_loss: 328.9655 - 55ms/epoch - 18ms/step
# Epoch 108/1000
# 3/3 - 0s - loss: 336.9350 - val_loss: 325.2710 - 64ms/epoch - 21ms/step
# Epoch 109/1000
# 3/3 - 0s - loss: 333.1180 - val_loss: 321.5844 - 66ms/epoch - 22ms/step
# Epoch 110/1000
# 3/3 - 0s - loss: 329.1620 - val_loss: 317.9054 - 62ms/epoch - 21ms/step
# Epoch 111/1000
# 3/3 - 0s - loss: 325.4318 - val_loss: 314.1766 - 65ms/epoch - 22ms/step
# Epoch 112/1000
# 3/3 - 0s - loss: 321.5124 - val_loss: 310.4857 - 66ms/epoch - 22ms/step
# Epoch 113/1000
# 3/3 - 0s - loss: 317.6262 - val_loss: 306.8361 - 51ms/epoch - 17ms/step
# Epoch 114/1000
# 3/3 - 0s - loss: 313.7851 - val_loss: 303.1647 - 56ms/epoch - 19ms/step
# Epoch 115/1000
# 3/3 - 0s - loss: 309.9530 - val_loss: 299.4988 - 54ms/epoch - 18ms/step
# Epoch 116/1000
# 3/3 - 0s - loss: 306.1731 - val_loss: 295.8356 - 73ms/epoch - 24ms/step
# Epoch 117/1000
# 3/3 - 0s - loss: 302.4107 - val_loss: 292.2006 - 59ms/epoch - 20ms/step
# Epoch 118/1000
# 3/3 - 0s - loss: 298.5897 - val_loss: 288.6248 - 62ms/epoch - 21ms/step
# Epoch 119/1000
# 3/3 - 0s - loss: 294.7531 - val_loss: 285.0461 - 63ms/epoch - 21ms/step
# Epoch 120/1000
# 3/3 - 0s - loss: 290.9670 - val_loss: 281.4745 - 53ms/epoch - 18ms/step
# Epoch 121/1000
# 3/3 - 0s - loss: 287.2302 - val_loss: 277.8799 - 57ms/epoch - 19ms/step
# Epoch 122/1000
# 3/3 - 0s - loss: 283.5154 - val_loss: 274.2646 - 69ms/epoch - 23ms/step
# Epoch 123/1000
# 3/3 - 0s - loss: 279.7336 - val_loss: 270.6864 - 62ms/epoch - 21ms/step
# Epoch 124/1000
# 3/3 - 0s - loss: 275.9179 - val_loss: 267.1269 - 90ms/epoch - 30ms/step
# Epoch 125/1000
# 3/3 - 0s - loss: 272.2375 - val_loss: 263.5569 - 70ms/epoch - 23ms/step
# Epoch 126/1000
# 3/3 - 0s - loss: 268.3950 - val_loss: 260.0380 - 136ms/epoch - 45ms/step
# Epoch 127/1000
# 3/3 - 0s - loss: 264.8073 - val_loss: 256.5005 - 62ms/epoch - 21ms/step
# Epoch 128/1000
# 3/3 - 0s - loss: 261.0687 - val_loss: 252.9924 - 78ms/epoch - 26ms/step
# Epoch 129/1000
# 3/3 - 0s - loss: 257.4497 - val_loss: 249.5028 - 73ms/epoch - 24ms/step
# Epoch 130/1000
# 3/3 - 0s - loss: 253.7801 - val_loss: 246.0165 - 73ms/epoch - 24ms/step
# Epoch 131/1000
# 3/3 - 0s - loss: 250.0979 - val_loss: 242.5929 - 60ms/epoch - 20ms/step
# Epoch 132/1000
# 3/3 - 0s - loss: 246.5528 - val_loss: 239.1833 - 74ms/epoch - 25ms/step
# Epoch 133/1000
# 3/3 - 0s - loss: 242.9286 - val_loss: 235.8156 - 58ms/epoch - 19ms/step
# Epoch 134/1000
# 3/3 - 0s - loss: 239.4278 - val_loss: 232.4871 - 68ms/epoch - 23ms/step
# Epoch 135/1000
# 3/3 - 0s - loss: 235.9227 - val_loss: 229.1513 - 56ms/epoch - 19ms/step
# Epoch 136/1000
# 3/3 - 0s - loss: 232.4448 - val_loss: 225.8598 - 80ms/epoch - 27ms/step
# Epoch 137/1000
# 3/3 - 0s - loss: 228.9929 - val_loss: 222.5926 - 62ms/epoch - 21ms/step
# Epoch 138/1000
# 3/3 - 0s - loss: 225.5380 - val_loss: 219.3646 - 83ms/epoch - 28ms/step
# Epoch 139/1000
# 3/3 - 0s - loss: 222.1655 - val_loss: 216.1696 - 66ms/epoch - 22ms/step
# Epoch 140/1000
# 3/3 - 0s - loss: 218.8578 - val_loss: 212.9857 - 69ms/epoch - 23ms/step
# Epoch 141/1000
# 3/3 - 0s - loss: 215.5320 - val_loss: 209.8575 - 70ms/epoch - 23ms/step
# Epoch 142/1000
# 3/3 - 0s - loss: 212.2073 - val_loss: 206.7652 - 70ms/epoch - 23ms/step
# Epoch 143/1000
# 3/3 - 0s - loss: 208.8547 - val_loss: 203.6690 - 67ms/epoch - 22ms/step
# Epoch 144/1000
# 3/3 - 0s - loss: 205.7180 - val_loss: 200.6091 - 55ms/epoch - 18ms/step
# Epoch 145/1000
# 3/3 - 0s - loss: 202.4986 - val_loss: 197.5821 - 55ms/epoch - 18ms/step
# Epoch 146/1000
# 3/3 - 0s - loss: 199.2768 - val_loss: 194.5960 - 73ms/epoch - 24ms/step
# Epoch 147/1000
# 3/3 - 0s - loss: 196.1733 - val_loss: 191.6099 - 55ms/epoch - 18ms/step
# Epoch 148/1000
# 3/3 - 0s - loss: 193.0409 - val_loss: 188.6823 - 70ms/epoch - 23ms/step
# Epoch 149/1000
# 3/3 - 0s - loss: 189.9387 - val_loss: 185.7567 - 54ms/epoch - 18ms/step
# Epoch 150/1000
# 3/3 - 0s - loss: 186.9347 - val_loss: 182.8639 - 60ms/epoch - 20ms/step
# Epoch 151/1000
# 3/3 - 0s - loss: 183.8823 - val_loss: 180.0144 - 65ms/epoch - 22ms/step
# Epoch 152/1000
# 3/3 - 0s - loss: 180.8990 - val_loss: 177.1834 - 48ms/epoch - 16ms/step
# Epoch 153/1000
# 3/3 - 0s - loss: 177.9348 - val_loss: 174.4176 - 53ms/epoch - 18ms/step
# Epoch 154/1000
# 3/3 - 0s - loss: 175.0982 - val_loss: 171.6443 - 56ms/epoch - 19ms/step
# Epoch 155/1000
# 3/3 - 0s - loss: 172.2085 - val_loss: 168.9461 - 75ms/epoch - 25ms/step
# Epoch 156/1000
# 3/3 - 0s - loss: 169.3167 - val_loss: 166.2801 - 58ms/epoch - 19ms/step
# Epoch 157/1000
# 3/3 - 0s - loss: 166.5854 - val_loss: 163.6280 - 66ms/epoch - 22ms/step
# Epoch 158/1000
# 3/3 - 0s - loss: 163.7935 - val_loss: 161.0346 - 68ms/epoch - 23ms/step
# Epoch 159/1000
# 3/3 - 0s - loss: 161.1056 - val_loss: 158.4739 - 64ms/epoch - 21ms/step
# Epoch 160/1000
# 3/3 - 0s - loss: 158.4337 - val_loss: 155.9597 - 53ms/epoch - 18ms/step
# Epoch 161/1000
# 3/3 - 0s - loss: 155.8256 - val_loss: 153.4868 - 58ms/epoch - 19ms/step
# Epoch 162/1000
# 3/3 - 0s - loss: 153.2768 - val_loss: 151.0679 - 100ms/epoch - 33ms/step
# Epoch 163/1000
# 3/3 - 0s - loss: 150.6990 - val_loss: 148.6889 - 58ms/epoch - 19ms/step
# Epoch 164/1000
# 3/3 - 0s - loss: 148.2305 - val_loss: 146.3361 - 59ms/epoch - 20ms/step
# Epoch 165/1000
# 3/3 - 0s - loss: 145.7548 - val_loss: 144.0277 - 58ms/epoch - 19ms/step
# Epoch 166/1000
# 3/3 - 0s - loss: 143.3591 - val_loss: 141.7321 - 69ms/epoch - 23ms/step
# Epoch 167/1000
# 3/3 - 0s - loss: 140.9278 - val_loss: 139.4938 - 66ms/epoch - 22ms/step
# Epoch 168/1000
# 3/3 - 0s - loss: 138.6226 - val_loss: 137.2640 - 63ms/epoch - 21ms/step
# Epoch 169/1000
# 3/3 - 0s - loss: 136.2928 - val_loss: 135.0753 - 57ms/epoch - 19ms/step
# Epoch 170/1000
# 3/3 - 0s - loss: 133.9980 - val_loss: 132.9470 - 56ms/epoch - 19ms/step
# Epoch 171/1000
# 3/3 - 0s - loss: 131.8104 - val_loss: 130.8427 - 79ms/epoch - 26ms/step
# Epoch 172/1000
# 3/3 - 0s - loss: 129.5773 - val_loss: 128.7893 - 72ms/epoch - 24ms/step
# Epoch 173/1000
# 3/3 - 0s - loss: 127.4611 - val_loss: 126.7758 - 68ms/epoch - 23ms/step
# Epoch 174/1000
# 3/3 - 0s - loss: 125.3613 - val_loss: 124.7953 - 72ms/epoch - 24ms/step
# Epoch 175/1000
# 3/3 - 0s - loss: 123.2745 - val_loss: 122.8654 - 66ms/epoch - 22ms/step
# Epoch 176/1000
# 3/3 - 0s - loss: 121.2722 - val_loss: 120.9314 - 62ms/epoch - 21ms/step
# Epoch 177/1000
# 3/3 - 0s - loss: 119.2604 - val_loss: 119.0501 - 72ms/epoch - 24ms/step
# Epoch 178/1000
# 3/3 - 0s - loss: 117.3239 - val_loss: 117.2052 - 60ms/epoch - 20ms/step
# Epoch 179/1000
# 3/3 - 0s - loss: 115.3837 - val_loss: 115.4097 - 67ms/epoch - 22ms/step
# Epoch 180/1000
# 3/3 - 0s - loss: 113.5226 - val_loss: 113.6410 - 58ms/epoch - 19ms/step
# Epoch 181/1000
# 3/3 - 0s - loss: 111.6695 - val_loss: 111.9129 - 61ms/epoch - 20ms/step
# Epoch 182/1000
# 3/3 - 0s - loss: 109.8710 - val_loss: 110.2163 - 58ms/epoch - 19ms/step
# Epoch 183/1000
# 3/3 - 0s - loss: 108.0891 - val_loss: 108.5488 - 45ms/epoch - 15ms/step
# Epoch 184/1000
# 3/3 - 0s - loss: 106.3724 - val_loss: 106.8945 - 72ms/epoch - 24ms/step
# Epoch 185/1000
# 3/3 - 0s - loss: 104.6552 - val_loss: 105.2944 - 71ms/epoch - 24ms/step
# Epoch 186/1000
# 3/3 - 0s - loss: 102.9872 - val_loss: 103.7112 - 74ms/epoch - 25ms/step
# Epoch 187/1000
# 3/3 - 0s - loss: 101.3491 - val_loss: 102.1597 - 58ms/epoch - 19ms/step
# Epoch 188/1000
# 3/3 - 0s - loss: 99.7535 - val_loss: 100.6561 - 70ms/epoch - 23ms/step
# Epoch 189/1000
# 3/3 - 0s - loss: 98.1875 - val_loss: 99.1696 - 54ms/epoch - 18ms/step
# Epoch 190/1000
# 3/3 - 0s - loss: 96.6341 - val_loss: 97.7348 - 69ms/epoch - 23ms/step
# Epoch 191/1000
# 3/3 - 0s - loss: 95.1633 - val_loss: 96.3076 - 65ms/epoch - 22ms/step
# Epoch 192/1000
# 3/3 - 0s - loss: 93.6835 - val_loss: 94.9327 - 57ms/epoch - 19ms/step
# Epoch 193/1000
# 3/3 - 0s - loss: 92.2545 - val_loss: 93.5756 - 100ms/epoch - 33ms/step
# Epoch 194/1000
# 3/3 - 0s - loss: 90.8672 - val_loss: 92.2413 - 57ms/epoch - 19ms/step
# Epoch 195/1000
# 3/3 - 0s - loss: 89.4946 - val_loss: 90.9481 - 67ms/epoch - 22ms/step
# Epoch 196/1000
# 3/3 - 0s - loss: 88.1254 - val_loss: 89.6674 - 69ms/epoch - 23ms/step
# Epoch 197/1000
# 3/3 - 0s - loss: 86.8397 - val_loss: 88.4145 - 75ms/epoch - 25ms/step
# Epoch 198/1000
# 3/3 - 0s - loss: 85.5609 - val_loss: 87.1913 - 74ms/epoch - 25ms/step
# Epoch 199/1000
# 3/3 - 0s - loss: 84.2836 - val_loss: 86.0092 - 68ms/epoch - 23ms/step
# Epoch 200/1000
# 3/3 - 0s - loss: 83.0686 - val_loss: 84.8247 - 67ms/epoch - 22ms/step
# Epoch 201/1000
# 3/3 - 0s - loss: 81.8644 - val_loss: 83.6954 - 67ms/epoch - 22ms/step
# Epoch 202/1000
# 3/3 - 0s - loss: 80.6944 - val_loss: 82.5832 - 66ms/epoch - 22ms/step
# Epoch 203/1000
# 3/3 - 0s - loss: 79.5492 - val_loss: 81.5059 - 50ms/epoch - 17ms/step
# Epoch 204/1000
# 3/3 - 0s - loss: 78.4401 - val_loss: 80.4321 - 74ms/epoch - 25ms/step
# Epoch 205/1000
# 3/3 - 0s - loss: 77.3355 - val_loss: 79.3923 - 60ms/epoch - 20ms/step
# Epoch 206/1000
# 3/3 - 0s - loss: 76.2837 - val_loss: 78.3664 - 56ms/epoch - 19ms/step
# Epoch 207/1000
# 3/3 - 0s - loss: 75.2468 - val_loss: 77.3654 - 59ms/epoch - 20ms/step
# Epoch 208/1000
# 3/3 - 0s - loss: 74.2231 - val_loss: 76.3891 - 50ms/epoch - 17ms/step
# Epoch 209/1000
# 3/3 - 0s - loss: 73.2266 - val_loss: 75.4304 - 50ms/epoch - 17ms/step
# Epoch 210/1000
# 3/3 - 0s - loss: 72.2383 - val_loss: 74.4963 - 58ms/epoch - 19ms/step
# Epoch 211/1000
# 3/3 - 0s - loss: 71.3046 - val_loss: 73.5831 - 67ms/epoch - 22ms/step
# Epoch 212/1000
# 3/3 - 0s - loss: 70.3767 - val_loss: 72.6766 - 61ms/epoch - 20ms/step
# Epoch 213/1000
# 3/3 - 0s - loss: 69.4531 - val_loss: 71.8074 - 47ms/epoch - 16ms/step
# Epoch 214/1000
# 3/3 - 0s - loss: 68.5828 - val_loss: 70.9425 - 68ms/epoch - 23ms/step
# Epoch 215/1000
# 3/3 - 0s - loss: 67.7087 - val_loss: 70.1036 - 40ms/epoch - 13ms/step
# Epoch 216/1000
# 3/3 - 0s - loss: 66.8729 - val_loss: 69.2883 - 58ms/epoch - 19ms/step
# Epoch 217/1000
# 3/3 - 0s - loss: 66.0158 - val_loss: 68.4957 - 58ms/epoch - 19ms/step
# Epoch 218/1000
# 3/3 - 0s - loss: 65.2250 - val_loss: 67.7169 - 67ms/epoch - 22ms/step
# Epoch 219/1000
# 3/3 - 0s - loss: 64.4426 - val_loss: 66.9499 - 80ms/epoch - 27ms/step
# Epoch 220/1000
# 3/3 - 0s - loss: 63.6591 - val_loss: 66.2124 - 70ms/epoch - 23ms/step
# Epoch 221/1000
# 3/3 - 0s - loss: 62.9366 - val_loss: 65.4710 - 73ms/epoch - 24ms/step
# Epoch 222/1000
# 3/3 - 0s - loss: 62.1830 - val_loss: 64.7654 - 74ms/epoch - 25ms/step
# Epoch 223/1000
# 3/3 - 0s - loss: 61.4640 - val_loss: 64.0762 - 67ms/epoch - 22ms/step
# Epoch 224/1000
# 3/3 - 0s - loss: 60.7631 - val_loss: 63.3854 - 66ms/epoch - 22ms/step
# Epoch 225/1000
# 3/3 - 0s - loss: 60.0808 - val_loss: 62.7237 - 67ms/epoch - 22ms/step
# Epoch 226/1000
# 3/3 - 0s - loss: 59.4181 - val_loss: 62.0644 - 77ms/epoch - 26ms/step
# Epoch 227/1000
# 3/3 - 0s - loss: 58.7578 - val_loss: 61.4280 - 64ms/epoch - 21ms/step
# Epoch 228/1000
# 3/3 - 0s - loss: 58.1278 - val_loss: 60.7879 - 97ms/epoch - 32ms/step
# Epoch 229/1000
# 3/3 - 0s - loss: 57.4955 - val_loss: 60.1817 - 64ms/epoch - 21ms/step
# Epoch 230/1000
# 3/3 - 0s - loss: 56.8716 - val_loss: 59.5844 - 70ms/epoch - 23ms/step
# Epoch 231/1000
# 3/3 - 0s - loss: 56.2874 - val_loss: 58.9957 - 68ms/epoch - 23ms/step
# Epoch 232/1000
# 3/3 - 0s - loss: 55.6892 - val_loss: 58.4189 - 73ms/epoch - 24ms/step
# Epoch 233/1000
# 3/3 - 0s - loss: 55.1290 - val_loss: 57.8467 - 72ms/epoch - 24ms/step
# Epoch 234/1000
# 3/3 - 0s - loss: 54.5597 - val_loss: 57.3035 - 73ms/epoch - 24ms/step
# Epoch 235/1000
# 3/3 - 0s - loss: 54.0163 - val_loss: 56.7536 - 64ms/epoch - 21ms/step
# Epoch 236/1000
# 3/3 - 0s - loss: 53.4807 - val_loss: 56.2288 - 70ms/epoch - 23ms/step
# Epoch 237/1000
# 3/3 - 0s - loss: 52.9521 - val_loss: 55.7179 - 44ms/epoch - 15ms/step
# Epoch 238/1000
# 3/3 - 0s - loss: 52.4449 - val_loss: 55.2028 - 58ms/epoch - 19ms/step
# Epoch 239/1000
# 3/3 - 0s - loss: 51.9500 - val_loss: 54.7151 - 60ms/epoch - 20ms/step
# Epoch 240/1000
# 3/3 - 0s - loss: 51.4709 - val_loss: 54.2169 - 56ms/epoch - 19ms/step
# Epoch 241/1000
# 3/3 - 0s - loss: 50.9852 - val_loss: 53.7451 - 61ms/epoch - 20ms/step
# Epoch 242/1000
# 3/3 - 0s - loss: 50.5185 - val_loss: 53.2909 - 71ms/epoch - 24ms/step
# Epoch 243/1000
# 3/3 - 0s - loss: 50.0637 - val_loss: 52.8366 - 67ms/epoch - 22ms/step
# Epoch 244/1000
# 3/3 - 0s - loss: 49.6176 - val_loss: 52.3977 - 57ms/epoch - 19ms/step
# Epoch 245/1000
# 3/3 - 0s - loss: 49.1929 - val_loss: 51.9561 - 50ms/epoch - 17ms/step
# Epoch 246/1000
# 3/3 - 0s - loss: 48.7572 - val_loss: 51.5280 - 66ms/epoch - 22ms/step
# Epoch 247/1000
# 3/3 - 0s - loss: 48.3415 - val_loss: 51.1076 - 58ms/epoch - 19ms/step
# Epoch 248/1000
# 3/3 - 0s - loss: 47.9228 - val_loss: 50.6968 - 58ms/epoch - 19ms/step
# Epoch 249/1000
# 3/3 - 0s - loss: 47.5243 - val_loss: 50.2999 - 58ms/epoch - 19ms/step
# Epoch 250/1000
# 3/3 - 0s - loss: 47.1333 - val_loss: 49.8987 - 58ms/epoch - 19ms/step
# Epoch 251/1000
# 3/3 - 0s - loss: 46.7536 - val_loss: 49.5030 - 59ms/epoch - 20ms/step
# Epoch 252/1000
# 3/3 - 0s - loss: 46.3607 - val_loss: 49.1279 - 50ms/epoch - 17ms/step
# Epoch 253/1000
# 3/3 - 0s - loss: 45.9901 - val_loss: 48.7447 - 60ms/epoch - 20ms/step
# Epoch 254/1000
# 3/3 - 0s - loss: 45.6247 - val_loss: 48.3756 - 56ms/epoch - 19ms/step
# Epoch 255/1000
# 3/3 - 0s - loss: 45.2569 - val_loss: 48.0117 - 74ms/epoch - 25ms/step
# Epoch 256/1000
# 3/3 - 0s - loss: 44.9191 - val_loss: 47.6529 - 56ms/epoch - 19ms/step
# Epoch 257/1000
# 3/3 - 0s - loss: 44.5686 - val_loss: 47.3061 - 66ms/epoch - 22ms/step
# Epoch 258/1000
# 3/3 - 0s - loss: 44.2237 - val_loss: 46.9601 - 84ms/epoch - 28ms/step
# Epoch 259/1000
# 3/3 - 0s - loss: 43.8877 - val_loss: 46.6229 - 123ms/epoch - 41ms/step
# Epoch 260/1000
# 3/3 - 0s - loss: 43.5459 - val_loss: 46.2844 - 74ms/epoch - 25ms/step
# Epoch 261/1000
# 3/3 - 0s - loss: 43.2403 - val_loss: 45.9522 - 66ms/epoch - 22ms/step
# Epoch 262/1000
# 3/3 - 0s - loss: 42.9031 - val_loss: 45.6296 - 65ms/epoch - 22ms/step
# Epoch 263/1000
# 3/3 - 0s - loss: 42.6050 - val_loss: 45.3076 - 55ms/epoch - 18ms/step
# Epoch 264/1000
# 3/3 - 0s - loss: 42.2775 - val_loss: 45.0009 - 76ms/epoch - 25ms/step
# Epoch 265/1000
# 3/3 - 0s - loss: 41.9869 - val_loss: 44.6925 - 71ms/epoch - 24ms/step
# Epoch 266/1000
# 3/3 - 0s - loss: 41.6818 - val_loss: 44.3873 - 78ms/epoch - 26ms/step
# Epoch 267/1000
# 3/3 - 0s - loss: 41.3938 - val_loss: 44.0898 - 72ms/epoch - 24ms/step
# Epoch 268/1000
# 3/3 - 0s - loss: 41.1064 - val_loss: 43.7942 - 60ms/epoch - 20ms/step
# Epoch 269/1000
# 3/3 - 0s - loss: 40.8267 - val_loss: 43.5006 - 55ms/epoch - 18ms/step
# Epoch 270/1000
# 3/3 - 0s - loss: 40.5466 - val_loss: 43.2089 - 62ms/epoch - 21ms/step
# Epoch 271/1000
# 3/3 - 0s - loss: 40.2723 - val_loss: 42.9315 - 61ms/epoch - 20ms/step
# Epoch 272/1000
# 3/3 - 0s - loss: 39.9963 - val_loss: 42.6485 - 54ms/epoch - 18ms/step
# Epoch 273/1000
# 3/3 - 0s - loss: 39.7239 - val_loss: 42.3762 - 60ms/epoch - 20ms/step
# Epoch 274/1000
# 3/3 - 0s - loss: 39.4694 - val_loss: 42.1040 - 57ms/epoch - 19ms/step
# Epoch 275/1000
# 3/3 - 0s - loss: 39.2038 - val_loss: 41.8334 - 53ms/epoch - 18ms/step
# Epoch 276/1000
# 3/3 - 0s - loss: 38.9430 - val_loss: 41.5705 - 57ms/epoch - 19ms/step
# Epoch 277/1000
# 3/3 - 0s - loss: 38.6859 - val_loss: 41.3076 - 58ms/epoch - 19ms/step
# Epoch 278/1000
# 3/3 - 0s - loss: 38.4531 - val_loss: 41.0437 - 64ms/epoch - 21ms/step
# Epoch 279/1000
# 3/3 - 0s - loss: 38.1897 - val_loss: 40.7995 - 50ms/epoch - 17ms/step
# Epoch 280/1000
# 3/3 - 0s - loss: 37.9478 - val_loss: 40.5402 - 62ms/epoch - 21ms/step
# Epoch 281/1000
# 3/3 - 0s - loss: 37.7150 - val_loss: 40.2955 - 58ms/epoch - 19ms/step
# Epoch 282/1000
# 3/3 - 0s - loss: 37.4765 - val_loss: 40.0581 - 74ms/epoch - 25ms/step
# Epoch 283/1000
# 3/3 - 0s - loss: 37.2466 - val_loss: 39.8217 - 51ms/epoch - 17ms/step
# Epoch 284/1000
# 3/3 - 0s - loss: 37.0211 - val_loss: 39.5871 - 66ms/epoch - 22ms/step
# Epoch 285/1000
# 3/3 - 0s - loss: 36.7913 - val_loss: 39.3541 - 56ms/epoch - 19ms/step
# Epoch 286/1000
# 3/3 - 0s - loss: 36.5733 - val_loss: 39.1208 - 70ms/epoch - 23ms/step
# Epoch 287/1000
# 3/3 - 0s - loss: 36.3564 - val_loss: 38.8947 - 50ms/epoch - 17ms/step
# Epoch 288/1000
# 3/3 - 0s - loss: 36.1363 - val_loss: 38.6811 - 62ms/epoch - 21ms/step
# Epoch 289/1000
# 3/3 - 0s - loss: 35.9368 - val_loss: 38.4626 - 55ms/epoch - 18ms/step
# Epoch 290/1000
# 3/3 - 0s - loss: 35.7225 - val_loss: 38.2408 - 64ms/epoch - 21ms/step
# Epoch 291/1000
# 3/3 - 0s - loss: 35.5257 - val_loss: 38.0280 - 54ms/epoch - 18ms/step
# Epoch 292/1000
# 3/3 - 0s - loss: 35.3209 - val_loss: 37.8189 - 58ms/epoch - 19ms/step
# Epoch 293/1000
# 3/3 - 0s - loss: 35.1177 - val_loss: 37.6159 - 63ms/epoch - 21ms/step
# Epoch 294/1000
# 3/3 - 0s - loss: 34.9194 - val_loss: 37.4012 - 46ms/epoch - 15ms/step
# Epoch 295/1000
# 3/3 - 0s - loss: 34.7287 - val_loss: 37.1911 - 53ms/epoch - 18ms/step
# Epoch 296/1000
# 3/3 - 0s - loss: 34.5310 - val_loss: 36.9895 - 103ms/epoch - 34ms/step
# Epoch 297/1000
# 3/3 - 0s - loss: 34.3429 - val_loss: 36.7873 - 57ms/epoch - 19ms/step
# Epoch 298/1000
# 3/3 - 0s - loss: 34.1420 - val_loss: 36.5917 - 58ms/epoch - 19ms/step
# Epoch 299/1000
# 3/3 - 0s - loss: 33.9650 - val_loss: 36.3963 - 50ms/epoch - 17ms/step
# Epoch 300/1000
# 3/3 - 0s - loss: 33.7767 - val_loss: 36.2082 - 67ms/epoch - 22ms/step
# Epoch 301/1000
# 3/3 - 0s - loss: 33.5985 - val_loss: 36.0191 - 75ms/epoch - 25ms/step
# Epoch 302/1000
# 3/3 - 0s - loss: 33.4176 - val_loss: 35.8384 - 66ms/epoch - 22ms/step
# Epoch 303/1000
# 3/3 - 0s - loss: 33.2451 - val_loss: 35.6493 - 53ms/epoch - 18ms/step
# Epoch 304/1000
# 3/3 - 0s - loss: 33.0722 - val_loss: 35.4735 - 50ms/epoch - 17ms/step
# Epoch 305/1000
# 3/3 - 0s - loss: 32.9017 - val_loss: 35.3016 - 58ms/epoch - 19ms/step
# Epoch 306/1000
# 3/3 - 0s - loss: 32.7200 - val_loss: 35.1252 - 69ms/epoch - 23ms/step
# Epoch 307/1000
# 3/3 - 0s - loss: 32.5563 - val_loss: 34.9470 - 47ms/epoch - 16ms/step
# Epoch 308/1000
# 3/3 - 0s - loss: 32.3919 - val_loss: 34.7709 - 43ms/epoch - 14ms/step
# Epoch 309/1000
# 3/3 - 0s - loss: 32.2213 - val_loss: 34.5912 - 58ms/epoch - 19ms/step
# Epoch 310/1000
# 3/3 - 0s - loss: 32.0569 - val_loss: 34.4112 - 58ms/epoch - 19ms/step
# Epoch 311/1000
# 3/3 - 0s - loss: 31.8995 - val_loss: 34.2409 - 50ms/epoch - 17ms/step
# Epoch 312/1000
# 3/3 - 0s - loss: 31.7328 - val_loss: 34.0661 - 58ms/epoch - 19ms/step
# Epoch 313/1000
# 3/3 - 0s - loss: 31.5682 - val_loss: 33.9099 - 42ms/epoch - 14ms/step
# Epoch 314/1000
# 3/3 - 0s - loss: 31.4171 - val_loss: 33.7409 - 58ms/epoch - 19ms/step
# Epoch 315/1000
# 3/3 - 0s - loss: 31.2682 - val_loss: 33.5689 - 59ms/epoch - 20ms/step
# Epoch 316/1000
# 3/3 - 0s - loss: 31.1107 - val_loss: 33.4077 - 52ms/epoch - 17ms/step
# Epoch 317/1000
# 3/3 - 0s - loss: 30.9579 - val_loss: 33.2466 - 64ms/epoch - 21ms/step
# Epoch 318/1000
# 3/3 - 0s - loss: 30.8089 - val_loss: 33.0905 - 56ms/epoch - 19ms/step
# Epoch 319/1000
# 3/3 - 0s - loss: 30.6606 - val_loss: 32.9274 - 54ms/epoch - 18ms/step
# Epoch 320/1000
# 3/3 - 0s - loss: 30.5129 - val_loss: 32.7796 - 70ms/epoch - 23ms/step
# Epoch 321/1000
# 3/3 - 0s - loss: 30.3684 - val_loss: 32.6245 - 44ms/epoch - 15ms/step
# Epoch 322/1000
# 3/3 - 0s - loss: 30.2227 - val_loss: 32.4748 - 52ms/epoch - 17ms/step
# Epoch 323/1000
# 3/3 - 0s - loss: 30.0826 - val_loss: 32.3190 - 56ms/epoch - 19ms/step
# Epoch 324/1000
# 3/3 - 0s - loss: 29.9373 - val_loss: 32.1679 - 58ms/epoch - 19ms/step
# Epoch 325/1000
# 3/3 - 0s - loss: 29.7960 - val_loss: 32.0163 - 50ms/epoch - 17ms/step
# Epoch 326/1000
# 3/3 - 0s - loss: 29.6586 - val_loss: 31.8655 - 58ms/epoch - 19ms/step
# Epoch 327/1000
# 3/3 - 0s - loss: 29.5258 - val_loss: 31.7126 - 52ms/epoch - 17ms/step
# Epoch 328/1000
# 3/3 - 0s - loss: 29.3823 - val_loss: 31.5704 - 50ms/epoch - 17ms/step
# Epoch 329/1000
# 3/3 - 0s - loss: 29.2456 - val_loss: 31.4281 - 59ms/epoch - 20ms/step
# Epoch 330/1000
# 3/3 - 0s - loss: 29.1103 - val_loss: 31.2886 - 50ms/epoch - 17ms/step
# Epoch 331/1000
# 3/3 - 0s - loss: 28.9817 - val_loss: 31.1380 - 58ms/epoch - 19ms/step
# Epoch 332/1000
# 3/3 - 0s - loss: 28.8551 - val_loss: 30.9967 - 50ms/epoch - 17ms/step
# Epoch 333/1000
# 3/3 - 0s - loss: 28.7165 - val_loss: 30.8595 - 92ms/epoch - 31ms/step
# Epoch 334/1000
# 3/3 - 0s - loss: 28.5916 - val_loss: 30.7214 - 59ms/epoch - 20ms/step
# Epoch 335/1000
# 3/3 - 0s - loss: 28.4635 - val_loss: 30.5902 - 59ms/epoch - 20ms/step
# Epoch 336/1000
# 3/3 - 0s - loss: 28.3377 - val_loss: 30.4518 - 50ms/epoch - 17ms/step
# Epoch 337/1000
# 3/3 - 0s - loss: 28.2146 - val_loss: 30.3131 - 43ms/epoch - 14ms/step
# Epoch 338/1000
# 3/3 - 0s - loss: 28.0933 - val_loss: 30.1786 - 51ms/epoch - 17ms/step
# Epoch 339/1000
# 3/3 - 0s - loss: 27.9687 - val_loss: 30.0407 - 59ms/epoch - 20ms/step
# Epoch 340/1000
# 3/3 - 0s - loss: 27.8430 - val_loss: 29.9076 - 55ms/epoch - 18ms/step
# Epoch 341/1000
# 3/3 - 0s - loss: 27.7197 - val_loss: 29.7770 - 58ms/epoch - 19ms/step
# Epoch 342/1000
# 3/3 - 0s - loss: 27.6086 - val_loss: 29.6473 - 66ms/epoch - 22ms/step
# Epoch 343/1000
# 3/3 - 0s - loss: 27.4843 - val_loss: 29.5164 - 57ms/epoch - 19ms/step
# Epoch 344/1000
# 3/3 - 0s - loss: 27.3620 - val_loss: 29.4042 - 61ms/epoch - 20ms/step
# Epoch 345/1000
# 3/3 - 0s - loss: 27.2540 - val_loss: 29.2660 - 57ms/epoch - 19ms/step
# Epoch 346/1000
# 3/3 - 0s - loss: 27.1305 - val_loss: 29.1380 - 75ms/epoch - 25ms/step
# Epoch 347/1000
# 3/3 - 0s - loss: 27.0194 - val_loss: 29.0149 - 57ms/epoch - 19ms/step
# Epoch 348/1000
# 3/3 - 0s - loss: 26.9056 - val_loss: 28.8961 - 75ms/epoch - 25ms/step
# Epoch 349/1000
# 3/3 - 0s - loss: 26.7930 - val_loss: 28.7682 - 71ms/epoch - 24ms/step
# Epoch 350/1000
# 3/3 - 0s - loss: 26.6769 - val_loss: 28.6520 - 61ms/epoch - 20ms/step
# Epoch 351/1000
# 3/3 - 0s - loss: 26.5667 - val_loss: 28.5296 - 70ms/epoch - 23ms/step
# Epoch 352/1000
# 3/3 - 0s - loss: 26.4616 - val_loss: 28.4075 - 67ms/epoch - 22ms/step
# Epoch 353/1000
# 3/3 - 0s - loss: 26.3542 - val_loss: 28.2803 - 47ms/epoch - 16ms/step
# Epoch 354/1000
# 3/3 - 0s - loss: 26.2323 - val_loss: 28.1631 - 44ms/epoch - 15ms/step
# Epoch 355/1000
# 3/3 - 0s - loss: 26.1255 - val_loss: 28.0410 - 58ms/epoch - 19ms/step
# Epoch 356/1000
# 3/3 - 0s - loss: 26.0162 - val_loss: 27.9229 - 58ms/epoch - 19ms/step
# Epoch 357/1000
# 3/3 - 0s - loss: 25.9016 - val_loss: 27.7963 - 68ms/epoch - 23ms/step
# Epoch 358/1000
# 3/3 - 0s - loss: 25.7902 - val_loss: 27.6800 - 49ms/epoch - 16ms/step
# Epoch 359/1000
# 3/3 - 0s - loss: 25.6812 - val_loss: 27.5666 - 69ms/epoch - 23ms/step
# Epoch 360/1000
# 3/3 - 0s - loss: 25.5809 - val_loss: 27.4420 - 56ms/epoch - 19ms/step
# Epoch 361/1000
# 3/3 - 0s - loss: 25.4668 - val_loss: 27.3346 - 58ms/epoch - 19ms/step
# Epoch 362/1000
# 3/3 - 0s - loss: 25.3663 - val_loss: 27.2189 - 66ms/epoch - 22ms/step
# Epoch 363/1000
# 3/3 - 0s - loss: 25.2578 - val_loss: 27.1061 - 50ms/epoch - 17ms/step
# Epoch 364/1000
# 3/3 - 0s - loss: 25.1542 - val_loss: 26.9994 - 58ms/epoch - 19ms/step
# Epoch 365/1000
# 3/3 - 0s - loss: 25.0522 - val_loss: 26.8781 - 50ms/epoch - 17ms/step
# Epoch 366/1000
# 3/3 - 0s - loss: 24.9485 - val_loss: 26.7729 - 42ms/epoch - 14ms/step
# Epoch 367/1000
# 3/3 - 0s - loss: 24.8478 - val_loss: 26.6571 - 90ms/epoch - 30ms/step
# Epoch 368/1000
# 3/3 - 0s - loss: 24.7461 - val_loss: 26.5489 - 61ms/epoch - 20ms/step
# Epoch 369/1000
# 3/3 - 0s - loss: 24.6473 - val_loss: 26.4353 - 57ms/epoch - 19ms/step
# Epoch 370/1000
# 3/3 - 0s - loss: 24.5480 - val_loss: 26.3267 - 50ms/epoch - 17ms/step
# Epoch 371/1000
# 3/3 - 0s - loss: 24.4516 - val_loss: 26.2214 - 58ms/epoch - 19ms/step
# Epoch 372/1000
# 3/3 - 0s - loss: 24.3503 - val_loss: 26.1154 - 50ms/epoch - 17ms/step
# Epoch 373/1000
# 3/3 - 0s - loss: 24.2573 - val_loss: 26.0006 - 58ms/epoch - 19ms/step
# Epoch 374/1000
# 3/3 - 0s - loss: 24.1583 - val_loss: 25.8992 - 89ms/epoch - 30ms/step
# Epoch 375/1000
# 3/3 - 0s - loss: 24.0585 - val_loss: 25.7933 - 52ms/epoch - 17ms/step
# Epoch 376/1000
# 3/3 - 0s - loss: 23.9626 - val_loss: 25.6899 - 41ms/epoch - 14ms/step
# Epoch 377/1000
# 3/3 - 0s - loss: 23.8663 - val_loss: 25.5797 - 70ms/epoch - 23ms/step
# Epoch 378/1000
# 3/3 - 0s - loss: 23.7780 - val_loss: 25.4758 - 47ms/epoch - 16ms/step
# Epoch 379/1000
# 3/3 - 0s - loss: 23.6723 - val_loss: 25.3718 - 58ms/epoch - 19ms/step
# Epoch 380/1000
# 3/3 - 0s - loss: 23.5811 - val_loss: 25.2640 - 66ms/epoch - 22ms/step
# Epoch 381/1000
# 3/3 - 0s - loss: 23.4855 - val_loss: 25.1605 - 48ms/epoch - 16ms/step
# Epoch 382/1000
# 3/3 - 0s - loss: 23.3960 - val_loss: 25.0538 - 59ms/epoch - 20ms/step
# Epoch 383/1000
# 3/3 - 0s - loss: 23.3000 - val_loss: 24.9516 - 59ms/epoch - 20ms/step
# Epoch 384/1000
# 3/3 - 0s - loss: 23.2057 - val_loss: 24.8524 - 66ms/epoch - 22ms/step
# Epoch 385/1000
# 3/3 - 0s - loss: 23.1197 - val_loss: 24.7486 - 70ms/epoch - 23ms/step
# Epoch 386/1000
# 3/3 - 0s - loss: 23.0243 - val_loss: 24.6477 - 55ms/epoch - 18ms/step
# Epoch 387/1000
# 3/3 - 0s - loss: 22.9363 - val_loss: 24.5528 - 71ms/epoch - 24ms/step
# Epoch 388/1000
# 3/3 - 0s - loss: 22.8548 - val_loss: 24.4517 - 59ms/epoch - 20ms/step
# Epoch 389/1000
# 3/3 - 0s - loss: 22.7663 - val_loss: 24.3526 - 58ms/epoch - 19ms/step
# Epoch 390/1000
# 3/3 - 0s - loss: 22.6799 - val_loss: 24.2603 - 66ms/epoch - 22ms/step
# Epoch 391/1000
# 3/3 - 0s - loss: 22.5934 - val_loss: 24.1634 - 56ms/epoch - 19ms/step
# Epoch 392/1000
# 3/3 - 0s - loss: 22.5091 - val_loss: 24.0602 - 67ms/epoch - 22ms/step
# Epoch 393/1000
# 3/3 - 0s - loss: 22.4266 - val_loss: 23.9655 - 60ms/epoch - 20ms/step
# Epoch 394/1000
# 3/3 - 0s - loss: 22.3406 - val_loss: 23.8661 - 57ms/epoch - 19ms/step
# Epoch 395/1000
# 3/3 - 0s - loss: 22.2581 - val_loss: 23.7680 - 63ms/epoch - 21ms/step
# Epoch 396/1000
# 3/3 - 0s - loss: 22.1777 - val_loss: 23.6673 - 54ms/epoch - 18ms/step
# Epoch 397/1000
# 3/3 - 0s - loss: 22.0985 - val_loss: 23.5694 - 67ms/epoch - 22ms/step
# Epoch 398/1000
# 3/3 - 0s - loss: 22.0122 - val_loss: 23.4765 - 67ms/epoch - 22ms/step
# Epoch 399/1000
# 3/3 - 0s - loss: 21.9350 - val_loss: 23.3781 - 55ms/epoch - 18ms/step
# Epoch 400/1000
# 3/3 - 0s - loss: 21.8581 - val_loss: 23.2841 - 64ms/epoch - 21ms/step
# Epoch 401/1000
# 3/3 - 0s - loss: 21.7773 - val_loss: 23.1852 - 48ms/epoch - 16ms/step
# Epoch 402/1000
# 3/3 - 0s - loss: 21.6993 - val_loss: 23.0933 - 74ms/epoch - 25ms/step
# Epoch 403/1000
# 3/3 - 0s - loss: 21.6212 - val_loss: 22.9972 - 42ms/epoch - 14ms/step
# Epoch 404/1000
# 3/3 - 0s - loss: 21.5397 - val_loss: 22.9048 - 99ms/epoch - 33ms/step
# Epoch 405/1000
# 3/3 - 0s - loss: 21.4633 - val_loss: 22.8120 - 66ms/epoch - 22ms/step
# Epoch 406/1000
# 3/3 - 0s - loss: 21.3884 - val_loss: 22.7230 - 56ms/epoch - 19ms/step
# Epoch 407/1000
# 3/3 - 0s - loss: 21.3147 - val_loss: 22.6258 - 41ms/epoch - 14ms/step
# Epoch 408/1000
# 3/3 - 0s - loss: 21.2342 - val_loss: 22.5383 - 70ms/epoch - 23ms/step
# Epoch 409/1000
# 3/3 - 0s - loss: 21.1600 - val_loss: 22.4482 - 49ms/epoch - 16ms/step
# Epoch 410/1000
# 3/3 - 0s - loss: 21.0835 - val_loss: 22.3608 - 59ms/epoch - 20ms/step
# Epoch 411/1000
# 3/3 - 0s - loss: 21.0125 - val_loss: 22.2688 - 75ms/epoch - 25ms/step
# Epoch 412/1000
# 3/3 - 0s - loss: 20.9370 - val_loss: 22.1776 - 51ms/epoch - 17ms/step
# Epoch 413/1000
# 3/3 - 0s - loss: 20.8639 - val_loss: 22.0805 - 59ms/epoch - 20ms/step
# Epoch 414/1000
# 3/3 - 0s - loss: 20.7844 - val_loss: 21.9934 - 58ms/epoch - 19ms/step
# Epoch 415/1000
# 3/3 - 0s - loss: 20.7124 - val_loss: 21.9038 - 59ms/epoch - 20ms/step
# Epoch 416/1000
# 3/3 - 0s - loss: 20.6415 - val_loss: 21.8136 - 66ms/epoch - 22ms/step
# Epoch 417/1000
# 3/3 - 0s - loss: 20.5635 - val_loss: 21.7216 - 53ms/epoch - 18ms/step
# Epoch 418/1000
# 3/3 - 0s - loss: 20.4946 - val_loss: 21.6294 - 59ms/epoch - 20ms/step
# Epoch 419/1000
# 3/3 - 0s - loss: 20.4206 - val_loss: 21.5416 - 57ms/epoch - 19ms/step
# Epoch 420/1000
# 3/3 - 0s - loss: 20.3517 - val_loss: 21.4529 - 66ms/epoch - 22ms/step
# Epoch 421/1000
# 3/3 - 0s - loss: 20.2784 - val_loss: 21.3671 - 75ms/epoch - 25ms/step
# Epoch 422/1000
# 3/3 - 0s - loss: 20.2116 - val_loss: 21.2774 - 57ms/epoch - 19ms/step
# Epoch 423/1000
# 3/3 - 0s - loss: 20.1389 - val_loss: 21.1838 - 58ms/epoch - 19ms/step
# Epoch 424/1000
# 3/3 - 0s - loss: 20.0697 - val_loss: 21.0989 - 60ms/epoch - 20ms/step
# Epoch 425/1000
# 3/3 - 0s - loss: 20.0016 - val_loss: 21.0089 - 56ms/epoch - 19ms/step
# Epoch 426/1000
# 3/3 - 0s - loss: 19.9307 - val_loss: 20.9260 - 67ms/epoch - 22ms/step
# Epoch 427/1000
# 3/3 - 0s - loss: 19.8660 - val_loss: 20.8310 - 66ms/epoch - 22ms/step
# Epoch 428/1000
# 3/3 - 0s - loss: 19.7898 - val_loss: 20.7472 - 58ms/epoch - 19ms/step
# Epoch 429/1000
# 3/3 - 0s - loss: 19.7230 - val_loss: 20.6629 - 62ms/epoch - 21ms/step
# Epoch 430/1000
# 3/3 - 0s - loss: 19.6551 - val_loss: 20.5731 - 50ms/epoch - 17ms/step
# Epoch 431/1000
# 3/3 - 0s - loss: 19.5864 - val_loss: 20.4948 - 58ms/epoch - 19ms/step
# Epoch 432/1000
# 3/3 - 0s - loss: 19.5202 - val_loss: 20.4058 - 58ms/epoch - 19ms/step
# Epoch 433/1000
# 3/3 - 0s - loss: 19.4506 - val_loss: 20.3204 - 56ms/epoch - 19ms/step
# Epoch 434/1000
# 3/3 - 0s - loss: 19.3818 - val_loss: 20.2324 - 53ms/epoch - 18ms/step
# Epoch 435/1000
# 3/3 - 0s - loss: 19.3192 - val_loss: 20.1462 - 53ms/epoch - 18ms/step
# Epoch 436/1000
# 3/3 - 0s - loss: 19.2485 - val_loss: 20.0617 - 61ms/epoch - 20ms/step
# Epoch 437/1000
# 3/3 - 0s - loss: 19.1857 - val_loss: 19.9819 - 55ms/epoch - 18ms/step
# Epoch 438/1000
# 3/3 - 0s - loss: 19.1215 - val_loss: 19.8968 - 57ms/epoch - 19ms/step
# Epoch 439/1000
# 3/3 - 0s - loss: 19.0538 - val_loss: 19.8156 - 58ms/epoch - 19ms/step
# Epoch 440/1000
# 3/3 - 0s - loss: 18.9883 - val_loss: 19.7315 - 67ms/epoch - 22ms/step
# Epoch 441/1000
# 3/3 - 0s - loss: 18.9254 - val_loss: 19.6492 - 105ms/epoch - 35ms/step
# Epoch 442/1000
# 3/3 - 0s - loss: 18.8650 - val_loss: 19.5619 - 56ms/epoch - 19ms/step
# Epoch 443/1000
# 3/3 - 0s - loss: 18.7971 - val_loss: 19.4730 - 57ms/epoch - 19ms/step
# Epoch 444/1000
# 3/3 - 0s - loss: 18.7345 - val_loss: 19.3868 - 57ms/epoch - 19ms/step
# Epoch 445/1000
# 3/3 - 0s - loss: 18.6720 - val_loss: 19.3070 - 61ms/epoch - 20ms/step
# Epoch 446/1000
# 3/3 - 0s - loss: 18.6079 - val_loss: 19.2257 - 69ms/epoch - 23ms/step
# Epoch 447/1000
# 3/3 - 0s - loss: 18.5459 - val_loss: 19.1525 - 58ms/epoch - 19ms/step
# Epoch 448/1000
# 3/3 - 0s - loss: 18.4862 - val_loss: 19.0697 - 68ms/epoch - 23ms/step
# Epoch 449/1000
# 3/3 - 0s - loss: 18.4287 - val_loss: 18.9912 - 71ms/epoch - 24ms/step
# Epoch 450/1000
# 3/3 - 0s - loss: 18.3677 - val_loss: 18.9143 - 61ms/epoch - 20ms/step
# Epoch 451/1000
# 3/3 - 0s - loss: 18.3050 - val_loss: 18.8391 - 77ms/epoch - 26ms/step
# Epoch 452/1000
# 3/3 - 0s - loss: 18.2476 - val_loss: 18.7639 - 55ms/epoch - 18ms/step
# Epoch 453/1000
# 3/3 - 0s - loss: 18.1859 - val_loss: 18.6861 - 54ms/epoch - 18ms/step
# Epoch 454/1000
# 3/3 - 0s - loss: 18.1301 - val_loss: 18.6081 - 58ms/epoch - 19ms/step
# Epoch 455/1000
# 3/3 - 0s - loss: 18.0703 - val_loss: 18.5322 - 59ms/epoch - 20ms/step
# Epoch 456/1000
# 3/3 - 0s - loss: 18.0163 - val_loss: 18.4562 - 59ms/epoch - 20ms/step
# Epoch 457/1000
# 3/3 - 0s - loss: 17.9520 - val_loss: 18.3811 - 61ms/epoch - 20ms/step
# Epoch 458/1000
# 3/3 - 0s - loss: 17.8961 - val_loss: 18.3102 - 52ms/epoch - 17ms/step
# Epoch 459/1000
# 3/3 - 0s - loss: 17.8409 - val_loss: 18.2314 - 51ms/epoch - 17ms/step
# Epoch 460/1000
# 3/3 - 0s - loss: 17.7809 - val_loss: 18.1618 - 58ms/epoch - 19ms/step
# Epoch 461/1000
# 3/3 - 0s - loss: 17.7284 - val_loss: 18.0792 - 59ms/epoch - 20ms/step
# Epoch 462/1000
# 3/3 - 0s - loss: 17.6681 - val_loss: 18.0066 - 59ms/epoch - 20ms/step
# Epoch 463/1000
# 3/3 - 0s - loss: 17.6132 - val_loss: 17.9304 - 61ms/epoch - 20ms/step
# Epoch 464/1000
# 3/3 - 0s - loss: 17.5569 - val_loss: 17.8597 - 79ms/epoch - 26ms/step
# Epoch 465/1000
# 3/3 - 0s - loss: 17.5000 - val_loss: 17.7908 - 55ms/epoch - 18ms/step
# Epoch 466/1000
# 3/3 - 0s - loss: 17.4472 - val_loss: 17.7161 - 59ms/epoch - 20ms/step
# Epoch 467/1000
# 3/3 - 0s - loss: 17.3944 - val_loss: 17.6456 - 54ms/epoch - 18ms/step
# Epoch 468/1000
# 3/3 - 0s - loss: 17.3385 - val_loss: 17.5781 - 60ms/epoch - 20ms/step
# Epoch 469/1000
# 3/3 - 0s - loss: 17.2853 - val_loss: 17.5051 - 68ms/epoch - 23ms/step
# Epoch 470/1000
# 3/3 - 0s - loss: 17.2311 - val_loss: 17.4366 - 55ms/epoch - 18ms/step
# Epoch 471/1000
# 3/3 - 0s - loss: 17.1787 - val_loss: 17.3732 - 56ms/epoch - 19ms/step
# Epoch 472/1000
# 3/3 - 0s - loss: 17.1254 - val_loss: 17.3014 - 69ms/epoch - 23ms/step
# Epoch 473/1000
# 3/3 - 0s - loss: 17.0729 - val_loss: 17.2311 - 86ms/epoch - 29ms/step
# Epoch 474/1000
# 3/3 - 0s - loss: 17.0208 - val_loss: 17.1647 - 66ms/epoch - 22ms/step
# Epoch 475/1000
# 3/3 - 0s - loss: 16.9694 - val_loss: 17.0924 - 69ms/epoch - 23ms/step
# Epoch 476/1000
# 3/3 - 0s - loss: 16.9163 - val_loss: 17.0223 - 86ms/epoch - 29ms/step
# Epoch 477/1000
# 3/3 - 0s - loss: 16.8664 - val_loss: 16.9554 - 60ms/epoch - 20ms/step
# Epoch 478/1000
# 3/3 - 0s - loss: 16.8129 - val_loss: 16.8830 - 58ms/epoch - 19ms/step
# Epoch 479/1000
# 3/3 - 0s - loss: 16.7602 - val_loss: 16.8153 - 54ms/epoch - 18ms/step
# Epoch 480/1000
# 3/3 - 0s - loss: 16.7111 - val_loss: 16.7485 - 71ms/epoch - 24ms/step
# Epoch 481/1000
# 3/3 - 0s - loss: 16.6607 - val_loss: 16.6816 - 64ms/epoch - 21ms/step
# Epoch 482/1000
# 3/3 - 0s - loss: 16.6110 - val_loss: 16.6165 - 58ms/epoch - 19ms/step
# Epoch 483/1000
# 3/3 - 0s - loss: 16.5620 - val_loss: 16.5520 - 63ms/epoch - 21ms/step
# Epoch 484/1000
# 3/3 - 0s - loss: 16.5134 - val_loss: 16.4865 - 55ms/epoch - 18ms/step
# Epoch 485/1000
# 3/3 - 0s - loss: 16.4619 - val_loss: 16.4230 - 61ms/epoch - 20ms/step
# Epoch 486/1000
# 3/3 - 0s - loss: 16.4144 - val_loss: 16.3592 - 57ms/epoch - 19ms/step
# Epoch 487/1000
# 3/3 - 0s - loss: 16.3658 - val_loss: 16.2926 - 60ms/epoch - 20ms/step
# Epoch 488/1000
# 3/3 - 0s - loss: 16.3168 - val_loss: 16.2255 - 61ms/epoch - 20ms/step
# Epoch 489/1000
# 3/3 - 0s - loss: 16.2665 - val_loss: 16.1599 - 71ms/epoch - 24ms/step
# Epoch 490/1000
# 3/3 - 0s - loss: 16.2213 - val_loss: 16.0949 - 57ms/epoch - 19ms/step
# Epoch 491/1000
# 3/3 - 0s - loss: 16.1748 - val_loss: 16.0259 - 63ms/epoch - 21ms/step
# Epoch 492/1000
# 3/3 - 0s - loss: 16.1233 - val_loss: 15.9643 - 57ms/epoch - 19ms/step
# Epoch 493/1000
# 3/3 - 0s - loss: 16.0774 - val_loss: 15.8998 - 61ms/epoch - 20ms/step
# Epoch 494/1000
# 3/3 - 0s - loss: 16.0313 - val_loss: 15.8363 - 57ms/epoch - 19ms/step
# Epoch 495/1000
# 3/3 - 0s - loss: 15.9832 - val_loss: 15.7680 - 59ms/epoch - 20ms/step
# Epoch 496/1000
# 3/3 - 0s - loss: 15.9385 - val_loss: 15.7028 - 50ms/epoch - 17ms/step
# Epoch 497/1000
# 3/3 - 0s - loss: 15.8908 - val_loss: 15.6354 - 52ms/epoch - 17ms/step
# Epoch 498/1000
# 3/3 - 0s - loss: 15.8430 - val_loss: 15.5695 - 68ms/epoch - 23ms/step
# Epoch 499/1000
# 3/3 - 0s - loss: 15.7996 - val_loss: 15.5036 - 74ms/epoch - 25ms/step
# Epoch 500/1000
# 3/3 - 0s - loss: 15.7528 - val_loss: 15.4407 - 69ms/epoch - 23ms/step
# Epoch 501/1000
# 3/3 - 0s - loss: 15.7079 - val_loss: 15.3755 - 60ms/epoch - 20ms/step
# Epoch 502/1000
# 3/3 - 0s - loss: 15.6634 - val_loss: 15.3156 - 64ms/epoch - 21ms/step
# Epoch 503/1000
# 3/3 - 0s - loss: 15.6196 - val_loss: 15.2541 - 56ms/epoch - 19ms/step
# Epoch 504/1000
# 3/3 - 0s - loss: 15.5771 - val_loss: 15.1917 - 76ms/epoch - 25ms/step
# Epoch 505/1000
# 3/3 - 0s - loss: 15.5321 - val_loss: 15.1309 - 72ms/epoch - 24ms/step
# Epoch 506/1000
# 3/3 - 0s - loss: 15.4891 - val_loss: 15.0722 - 51ms/epoch - 17ms/step
# Epoch 507/1000
# 3/3 - 0s - loss: 15.4455 - val_loss: 15.0174 - 50ms/epoch - 17ms/step
# Epoch 508/1000
# 3/3 - 0s - loss: 15.4037 - val_loss: 14.9549 - 60ms/epoch - 20ms/step
# Epoch 509/1000
# 3/3 - 0s - loss: 15.3573 - val_loss: 14.9036 - 87ms/epoch - 29ms/step
# Epoch 510/1000
# 3/3 - 0s - loss: 15.3189 - val_loss: 14.8444 - 67ms/epoch - 22ms/step
# Epoch 511/1000
# 3/3 - 0s - loss: 15.2758 - val_loss: 14.7856 - 63ms/epoch - 21ms/step
# Epoch 512/1000
# 3/3 - 0s - loss: 15.2312 - val_loss: 14.7244 - 62ms/epoch - 21ms/step
# Epoch 513/1000
# 3/3 - 0s - loss: 15.1922 - val_loss: 14.6670 - 62ms/epoch - 21ms/step
# Epoch 514/1000
# 3/3 - 0s - loss: 15.1501 - val_loss: 14.6112 - 65ms/epoch - 22ms/step
# Epoch 515/1000
# 3/3 - 0s - loss: 15.1096 - val_loss: 14.5518 - 66ms/epoch - 22ms/step
# Epoch 516/1000
# 3/3 - 0s - loss: 15.0670 - val_loss: 14.4973 - 65ms/epoch - 22ms/step
# Epoch 517/1000
# 3/3 - 0s - loss: 15.0272 - val_loss: 14.4389 - 54ms/epoch - 18ms/step
# Epoch 518/1000
# 3/3 - 0s - loss: 14.9862 - val_loss: 14.3883 - 64ms/epoch - 21ms/step
# Epoch 519/1000
# 3/3 - 0s - loss: 14.9449 - val_loss: 14.3271 - 59ms/epoch - 20ms/step
# Epoch 520/1000
# 3/3 - 0s - loss: 14.9063 - val_loss: 14.2729 - 51ms/epoch - 17ms/step
# Epoch 521/1000
# 3/3 - 0s - loss: 14.8634 - val_loss: 14.2160 - 62ms/epoch - 21ms/step
# Epoch 522/1000
# 3/3 - 0s - loss: 14.8224 - val_loss: 14.1626 - 60ms/epoch - 20ms/step
# Epoch 523/1000
# 3/3 - 0s - loss: 14.7831 - val_loss: 14.1134 - 56ms/epoch - 19ms/step
# Epoch 524/1000
# 3/3 - 0s - loss: 14.7427 - val_loss: 14.0566 - 49ms/epoch - 16ms/step
# Epoch 525/1000
# 3/3 - 0s - loss: 14.7056 - val_loss: 14.0060 - 50ms/epoch - 17ms/step
# Epoch 526/1000
# 3/3 - 0s - loss: 14.6643 - val_loss: 13.9556 - 50ms/epoch - 17ms/step
# Epoch 527/1000
# 3/3 - 0s - loss: 14.6294 - val_loss: 13.9010 - 50ms/epoch - 17ms/step
# Epoch 528/1000
# 3/3 - 0s - loss: 14.5880 - val_loss: 13.8525 - 57ms/epoch - 19ms/step
# Epoch 529/1000
# 3/3 - 0s - loss: 14.5500 - val_loss: 13.8020 - 69ms/epoch - 23ms/step
# Epoch 530/1000
# 3/3 - 0s - loss: 14.5151 - val_loss: 13.7519 - 61ms/epoch - 20ms/step
# Epoch 531/1000
# 3/3 - 0s - loss: 14.4770 - val_loss: 13.7041 - 60ms/epoch - 20ms/step
# Epoch 532/1000
# 3/3 - 0s - loss: 14.4391 - val_loss: 13.6572 - 71ms/epoch - 24ms/step
# Epoch 533/1000
# 3/3 - 0s - loss: 14.4060 - val_loss: 13.6069 - 64ms/epoch - 21ms/step
# Epoch 534/1000
# 3/3 - 0s - loss: 14.3690 - val_loss: 13.5570 - 64ms/epoch - 21ms/step
# Epoch 535/1000
# 3/3 - 0s - loss: 14.3336 - val_loss: 13.5073 - 77ms/epoch - 26ms/step
# Epoch 536/1000
# 3/3 - 0s - loss: 14.2961 - val_loss: 13.4608 - 66ms/epoch - 22ms/step
# Epoch 537/1000
# 3/3 - 0s - loss: 14.2618 - val_loss: 13.4118 - 75ms/epoch - 25ms/step
# Epoch 538/1000
# 3/3 - 0s - loss: 14.2235 - val_loss: 13.3688 - 69ms/epoch - 23ms/step
# Epoch 539/1000
# 3/3 - 0s - loss: 14.1901 - val_loss: 13.3207 - 69ms/epoch - 23ms/step
# Epoch 540/1000
# 3/3 - 0s - loss: 14.1555 - val_loss: 13.2752 - 70ms/epoch - 23ms/step
# Epoch 541/1000
# 3/3 - 0s - loss: 14.1186 - val_loss: 13.2246 - 67ms/epoch - 22ms/step
# Epoch 542/1000
# 3/3 - 0s - loss: 14.0837 - val_loss: 13.1793 - 126ms/epoch - 42ms/step
# Epoch 543/1000
# 3/3 - 0s - loss: 14.0488 - val_loss: 13.1344 - 56ms/epoch - 19ms/step
# Epoch 544/1000
# 3/3 - 0s - loss: 14.0120 - val_loss: 13.0887 - 52ms/epoch - 17ms/step
# Epoch 545/1000
# 3/3 - 0s - loss: 13.9787 - val_loss: 13.0414 - 60ms/epoch - 20ms/step
# Epoch 546/1000
# 3/3 - 0s - loss: 13.9443 - val_loss: 12.9949 - 58ms/epoch - 19ms/step
# Epoch 547/1000
# 3/3 - 0s - loss: 13.9087 - val_loss: 12.9545 - 60ms/epoch - 20ms/step
# Epoch 548/1000
# 3/3 - 0s - loss: 13.8777 - val_loss: 12.9044 - 55ms/epoch - 18ms/step
# Epoch 549/1000
# 3/3 - 0s - loss: 13.8445 - val_loss: 12.8621 - 48ms/epoch - 16ms/step
# Epoch 550/1000
# 3/3 - 0s - loss: 13.8127 - val_loss: 12.8160 - 58ms/epoch - 19ms/step
# Epoch 551/1000
# 3/3 - 0s - loss: 13.7747 - val_loss: 12.7733 - 59ms/epoch - 20ms/step
# Epoch 552/1000
# 3/3 - 0s - loss: 13.7418 - val_loss: 12.7300 - 57ms/epoch - 19ms/step
# Epoch 553/1000
# 3/3 - 0s - loss: 13.7131 - val_loss: 12.6861 - 53ms/epoch - 18ms/step
# Epoch 554/1000
# 3/3 - 0s - loss: 13.6781 - val_loss: 12.6413 - 53ms/epoch - 18ms/step
# Epoch 555/1000
# 3/3 - 0s - loss: 13.6448 - val_loss: 12.5973 - 48ms/epoch - 16ms/step
# Epoch 556/1000
# 3/3 - 0s - loss: 13.6147 - val_loss: 12.5534 - 53ms/epoch - 18ms/step
# Epoch 557/1000
# 3/3 - 0s - loss: 13.5807 - val_loss: 12.5134 - 45ms/epoch - 15ms/step
# Epoch 558/1000
# 3/3 - 0s - loss: 13.5503 - val_loss: 12.4623 - 58ms/epoch - 19ms/step
# Epoch 559/1000
# 3/3 - 0s - loss: 13.5188 - val_loss: 12.4198 - 52ms/epoch - 17ms/step
# ...
# Epoch 788/1000
# 3/3 - 0s - loss: 9.6312 - val_loss: 7.1900 - 58ms/epoch - 19ms/step
# Epoch 789/1000
# 3/3 - 0s - loss: 9.6242 - val_loss: 7.1809 - 48ms/epoch - 16ms/step
# Epoch 790/1000
# 3/3 - 0s - loss: 9.6162 - val_loss: 7.1714 - 56ms/epoch - 19ms/step
# Epoch 791/1000
# 3/3 - 0s - loss: 9.6091 - val_loss: 7.1638 - 48ms/epoch - 16ms/step
# Epoch 792/1000
# 3/3 - 0s - loss: 9.6002 - val_loss: 7.1567 - 49ms/epoch - 16ms/step
# Epoch 793/1000
# 3/3 - 0s - loss: 9.5934 - val_loss: 7.1451 - 51ms/epoch - 17ms/step
# Epoch 794/1000
# 3/3 - 0s - loss: 9.5855 - val_loss: 7.1369 - 48ms/epoch - 16ms/step
# Epoch 795/1000
# 3/3 - 0s - loss: 9.5810 - val_loss: 7.1298 - 50ms/epoch - 17ms/step
# Epoch 796/1000
# 3/3 - 0s - loss: 9.5705 - val_loss: 7.1213 - 58ms/epoch - 19ms/step
# Epoch 797/1000
# 3/3 - 0s - loss: 9.5633 - val_loss: 7.1144 - 70ms/epoch - 23ms/step
# Epoch 798/1000
# 3/3 - 0s - loss: 9.5569 - val_loss: 7.1068 - 44ms/epoch - 15ms/step
# Epoch 799/1000
# 3/3 - 0s - loss: 9.5508 - val_loss: 7.0960 - 50ms/epoch - 17ms/step
# Epoch 800/1000
# 3/3 - 0s - loss: 9.5426 - val_loss: 7.0893 - 94ms/epoch - 31ms/step
# Epoch 801/1000
# 3/3 - 0s - loss: 9.5366 - val_loss: 7.0809 - 46ms/epoch - 15ms/step
# Epoch 802/1000
# 3/3 - 0s - loss: 9.5302 - val_loss: 7.0712 - 53ms/epoch - 18ms/step
# Epoch 803/1000
# 3/3 - 0s - loss: 9.5223 - val_loss: 7.0618 - 63ms/epoch - 21ms/step
# Epoch 804/1000
# 3/3 - 0s - loss: 9.5149 - val_loss: 7.0535 - 59ms/epoch - 20ms/step
# Epoch 805/1000
# 3/3 - 0s - loss: 9.5111 - val_loss: 7.0445 - 53ms/epoch - 18ms/step
# Epoch 806/1000
# 3/3 - 0s - loss: 9.5013 - val_loss: 7.0377 - 50ms/epoch - 17ms/step
# Epoch 807/1000
# 3/3 - 0s - loss: 9.4948 - val_loss: 7.0300 - 55ms/epoch - 18ms/step
# Epoch 808/1000
# 3/3 - 0s - loss: 9.4882 - val_loss: 7.0185 - 52ms/epoch - 17ms/step
# Epoch 809/1000
# 3/3 - 0s - loss: 9.4820 - val_loss: 7.0096 - 64ms/epoch - 21ms/step
# Epoch 810/1000
# 3/3 - 0s - loss: 9.4789 - val_loss: 6.9982 - 58ms/epoch - 19ms/step
# Epoch 811/1000
# 3/3 - 0s - loss: 9.4685 - val_loss: 6.9950 - 61ms/epoch - 20ms/step
# Epoch 812/1000
# 3/3 - 0s - loss: 9.4623 - val_loss: 6.9844 - 62ms/epoch - 21ms/step
# Epoch 813/1000
# 3/3 - 0s - loss: 9.4546 - val_loss: 6.9756 - 59ms/epoch - 20ms/step
# Epoch 814/1000
# 3/3 - 0s - loss: 9.4494 - val_loss: 6.9689 - 55ms/epoch - 18ms/step
# Epoch 815/1000
# 3/3 - 0s - loss: 9.4443 - val_loss: 6.9659 - 58ms/epoch - 19ms/step
# Epoch 816/1000
# 3/3 - 0s - loss: 9.4381 - val_loss: 6.9571 - 53ms/epoch - 18ms/step
# Epoch 817/1000
# 3/3 - 0s - loss: 9.4303 - val_loss: 6.9479 - 61ms/epoch - 20ms/step
# Epoch 818/1000
# 3/3 - 0s - loss: 9.4244 - val_loss: 6.9393 - 58ms/epoch - 19ms/step
# Epoch 819/1000
# 3/3 - 0s - loss: 9.4191 - val_loss: 6.9348 - 55ms/epoch - 18ms/step
# Epoch 820/1000
# 3/3 - 0s - loss: 9.4138 - val_loss: 6.9312 - 60ms/epoch - 20ms/step
# Epoch 821/1000
# 3/3 - 0s - loss: 9.4100 - val_loss: 6.9277 - 65ms/epoch - 22ms/step
# Epoch 822/1000
# 3/3 - 0s - loss: 9.3996 - val_loss: 6.9224 - 58ms/epoch - 19ms/step
# Epoch 823/1000
# 3/3 - 0s - loss: 9.3958 - val_loss: 6.9186 - 59ms/epoch - 20ms/step
# Epoch 824/1000
# 3/3 - 0s - loss: 9.3896 - val_loss: 6.9099 - 55ms/epoch - 18ms/step
# Epoch 825/1000
# 3/3 - 0s - loss: 9.3825 - val_loss: 6.9015 - 52ms/epoch - 17ms/step
# Epoch 826/1000
# 3/3 - 0s - loss: 9.3759 - val_loss: 6.8942 - 48ms/epoch - 16ms/step
# Epoch 827/1000
# 3/3 - 0s - loss: 9.3708 - val_loss: 6.8874 - 70ms/epoch - 23ms/step
# Epoch 828/1000
# 3/3 - 0s - loss: 9.3632 - val_loss: 6.8774 - 52ms/epoch - 17ms/step
# Epoch 829/1000
# 3/3 - 0s - loss: 9.3580 - val_loss: 6.8686 - 52ms/epoch - 17ms/step
# Epoch 830/1000
# 3/3 - 0s - loss: 9.3515 - val_loss: 6.8608 - 48ms/epoch - 16ms/step
# Epoch 831/1000
# 3/3 - 0s - loss: 9.3467 - val_loss: 6.8545 - 91ms/epoch - 30ms/step
# Epoch 832/1000
# 3/3 - 0s - loss: 9.3400 - val_loss: 6.8485 - 48ms/epoch - 16ms/step
# Epoch 833/1000
# 3/3 - 0s - loss: 9.3342 - val_loss: 6.8425 - 49ms/epoch - 16ms/step
# Epoch 834/1000
# 3/3 - 0s - loss: 9.3277 - val_loss: 6.8378 - 51ms/epoch - 17ms/step
# Epoch 835/1000
# 3/3 - 0s - loss: 9.3230 - val_loss: 6.8294 - 50ms/epoch - 17ms/step
# Epoch 836/1000
# 3/3 - 0s - loss: 9.3173 - val_loss: 6.8262 - 49ms/epoch - 16ms/step
# Epoch 837/1000
# 3/3 - 0s - loss: 9.3127 - val_loss: 6.8225 - 49ms/epoch - 16ms/step
# Epoch 838/1000
# 3/3 - 0s - loss: 9.3060 - val_loss: 6.8156 - 55ms/epoch - 18ms/step
# Epoch 839/1000
# 3/3 - 0s - loss: 9.2999 - val_loss: 6.8088 - 43ms/epoch - 14ms/step
# Epoch 840/1000
# 3/3 - 0s - loss: 9.2957 - val_loss: 6.8009 - 61ms/epoch - 20ms/step
# Epoch 841/1000
# 3/3 - 0s - loss: 9.2892 - val_loss: 6.7917 - 46ms/epoch - 15ms/step
# Epoch 842/1000
# 3/3 - 0s - loss: 9.2832 - val_loss: 6.7852 - 49ms/epoch - 16ms/step
# Epoch 843/1000
# 3/3 - 0s - loss: 9.2776 - val_loss: 6.7812 - 49ms/epoch - 16ms/step
# Epoch 844/1000
# 3/3 - 0s - loss: 9.2722 - val_loss: 6.7751 - 54ms/epoch - 18ms/step
# Epoch 845/1000
# 3/3 - 0s - loss: 9.2677 - val_loss: 6.7689 - 55ms/epoch - 18ms/step
# Epoch 846/1000
# 3/3 - 0s - loss: 9.2627 - val_loss: 6.7659 - 57ms/epoch - 19ms/step
# Epoch 847/1000
# 3/3 - 0s - loss: 9.2560 - val_loss: 6.7577 - 60ms/epoch - 20ms/step
# Epoch 848/1000
# 3/3 - 0s - loss: 9.2522 - val_loss: 6.7507 - 59ms/epoch - 20ms/step
# Epoch 849/1000
# 3/3 - 0s - loss: 9.2458 - val_loss: 6.7464 - 55ms/epoch - 18ms/step
# Epoch 850/1000
# 3/3 - 0s - loss: 9.2408 - val_loss: 6.7411 - 81ms/epoch - 27ms/step
# Epoch 851/1000
# 3/3 - 0s - loss: 9.2363 - val_loss: 6.7361 - 62ms/epoch - 21ms/step
# Epoch 852/1000
# 3/3 - 0s - loss: 9.2309 - val_loss: 6.7313 - 63ms/epoch - 21ms/step
# Epoch 853/1000
# 3/3 - 0s - loss: 9.2257 - val_loss: 6.7268 - 52ms/epoch - 17ms/step
# Epoch 854/1000
# 3/3 - 0s - loss: 9.2201 - val_loss: 6.7209 - 50ms/epoch - 17ms/step
# Epoch 855/1000
# 3/3 - 0s - loss: 9.2180 - val_loss: 6.7158 - 65ms/epoch - 22ms/step
# Epoch 856/1000
# 3/3 - 0s - loss: 9.2126 - val_loss: 6.7149 - 51ms/epoch - 17ms/step
# Epoch 857/1000
# 3/3 - 0s - loss: 9.2068 - val_loss: 6.7049 - 58ms/epoch - 19ms/step
# Epoch 858/1000
# 3/3 - 0s - loss: 9.2019 - val_loss: 6.6997 - 58ms/epoch - 19ms/step
# Epoch 859/1000
# 3/3 - 0s - loss: 9.1965 - val_loss: 6.6933 - 98ms/epoch - 33ms/step
# Epoch 860/1000
# 3/3 - 0s - loss: 9.1920 - val_loss: 6.6840 - 54ms/epoch - 18ms/step
# Epoch 861/1000
# 3/3 - 0s - loss: 9.1868 - val_loss: 6.6779 - 55ms/epoch - 18ms/step
# Epoch 862/1000
# 3/3 - 0s - loss: 9.1829 - val_loss: 6.6740 - 51ms/epoch - 17ms/step
# Epoch 863/1000
# 3/3 - 0s - loss: 9.1790 - val_loss: 6.6707 - 48ms/epoch - 16ms/step
# Epoch 864/1000
# 3/3 - 0s - loss: 9.1737 - val_loss: 6.6670 - 49ms/epoch - 16ms/step
# Epoch 865/1000
# 3/3 - 0s - loss: 9.1706 - val_loss: 6.6635 - 51ms/epoch - 17ms/step
# Epoch 866/1000
# 3/3 - 0s - loss: 9.1659 - val_loss: 6.6587 - 47ms/epoch - 16ms/step
# Epoch 867/1000
# 3/3 - 0s - loss: 9.1617 - val_loss: 6.6530 - 56ms/epoch - 19ms/step
# Epoch 868/1000
# 3/3 - 0s - loss: 9.1569 - val_loss: 6.6487 - 50ms/epoch - 17ms/step
# Epoch 869/1000
# 3/3 - 0s - loss: 9.1532 - val_loss: 6.6447 - 49ms/epoch - 16ms/step
# Epoch 870/1000
# 3/3 - 0s - loss: 9.1503 - val_loss: 6.6379 - 50ms/epoch - 17ms/step
# Epoch 871/1000
# 3/3 - 0s - loss: 9.1437 - val_loss: 6.6316 - 51ms/epoch - 17ms/step
# Epoch 872/1000
# 3/3 - 0s - loss: 9.1415 - val_loss: 6.6258 - 47ms/epoch - 16ms/step
# Epoch 873/1000
# 3/3 - 0s - loss: 9.1337 - val_loss: 6.6180 - 72ms/epoch - 24ms/step
# Epoch 874/1000
# 3/3 - 0s - loss: 9.1325 - val_loss: 6.6120 - 43ms/epoch - 14ms/step
# Epoch 875/1000
# 3/3 - 0s - loss: 9.1272 - val_loss: 6.6068 - 51ms/epoch - 17ms/step
# Epoch 876/1000
# 3/3 - 0s - loss: 9.1235 - val_loss: 6.6021 - 50ms/epoch - 17ms/step
# Epoch 877/1000
# 3/3 - 0s - loss: 9.1183 - val_loss: 6.5977 - 54ms/epoch - 18ms/step
# Epoch 878/1000
# 3/3 - 0s - loss: 9.1155 - val_loss: 6.5933 - 57ms/epoch - 19ms/step
# Epoch 879/1000
# 3/3 - 0s - loss: 9.1116 - val_loss: 6.5870 - 52ms/epoch - 17ms/step
# Epoch 880/1000
# 3/3 - 0s - loss: 9.1074 - val_loss: 6.5856 - 58ms/epoch - 19ms/step
# Epoch 881/1000
# 3/3 - 0s - loss: 9.1046 - val_loss: 6.5811 - 58ms/epoch - 19ms/step
# Epoch 882/1000
# 3/3 - 0s - loss: 9.0998 - val_loss: 6.5757 - 58ms/epoch - 19ms/step
# Epoch 883/1000
# 3/3 - 0s - loss: 9.0960 - val_loss: 6.5695 - 60ms/epoch - 20ms/step
# Epoch 884/1000
# 3/3 - 0s - loss: 9.0924 - val_loss: 6.5647 - 59ms/epoch - 20ms/step
# Epoch 885/1000
# 3/3 - 0s - loss: 9.0879 - val_loss: 6.5624 - 54ms/epoch - 18ms/step
# Epoch 886/1000
# 3/3 - 0s - loss: 9.0851 - val_loss: 6.5622 - 60ms/epoch - 20ms/step
# Epoch 887/1000
# 3/3 - 0s - loss: 9.0802 - val_loss: 6.5623 - 36ms/epoch - 12ms/step
# Epoch 888/1000
# 3/3 - 0s - loss: 9.0773 - val_loss: 6.5584 - 99ms/epoch - 33ms/step
# Epoch 889/1000
# 3/3 - 0s - loss: 9.0738 - val_loss: 6.5532 - 68ms/epoch - 23ms/step
# Epoch 890/1000
# 3/3 - 0s - loss: 9.0711 - val_loss: 6.5463 - 58ms/epoch - 19ms/step
# Epoch 891/1000
# 3/3 - 0s - loss: 9.0667 - val_loss: 6.5406 - 59ms/epoch - 20ms/step
# Epoch 892/1000
# 3/3 - 0s - loss: 9.0645 - val_loss: 6.5316 - 50ms/epoch - 17ms/step
# Epoch 893/1000
# 3/3 - 0s - loss: 9.0595 - val_loss: 6.5303 - 47ms/epoch - 16ms/step
# Epoch 894/1000
# 3/3 - 0s - loss: 9.0556 - val_loss: 6.5214 - 54ms/epoch - 18ms/step
# Epoch 895/1000
# 3/3 - 0s - loss: 9.0519 - val_loss: 6.5200 - 53ms/epoch - 18ms/step
# Epoch 896/1000
# 3/3 - 0s - loss: 9.0466 - val_loss: 6.5153 - 72ms/epoch - 24ms/step
# Epoch 897/1000
# 3/3 - 0s - loss: 9.0435 - val_loss: 6.5111 - 57ms/epoch - 19ms/step
# Epoch 898/1000
# 3/3 - 0s - loss: 9.0403 - val_loss: 6.5071 - 50ms/epoch - 17ms/step
# Epoch 899/1000
# 3/3 - 0s - loss: 9.0363 - val_loss: 6.5026 - 49ms/epoch - 16ms/step
# Epoch 900/1000
# 3/3 - 0s - loss: 9.0332 - val_loss: 6.4988 - 51ms/epoch - 17ms/step
# Epoch 901/1000
# 3/3 - 0s - loss: 9.0296 - val_loss: 6.4934 - 47ms/epoch - 16ms/step
# Epoch 902/1000
# 3/3 - 0s - loss: 9.0257 - val_loss: 6.4896 - 51ms/epoch - 17ms/step
# Epoch 903/1000
# 3/3 - 0s - loss: 9.0212 - val_loss: 6.4848 - 48ms/epoch - 16ms/step
# Epoch 904/1000
# 3/3 - 0s - loss: 9.0187 - val_loss: 6.4790 - 51ms/epoch - 17ms/step
# Epoch 905/1000
# 3/3 - 0s - loss: 9.0149 - val_loss: 6.4718 - 47ms/epoch - 16ms/step
# Epoch 906/1000
# 3/3 - 0s - loss: 9.0111 - val_loss: 6.4642 - 54ms/epoch - 18ms/step
# Epoch 907/1000
# 3/3 - 0s - loss: 9.0079 - val_loss: 6.4553 - 44ms/epoch - 15ms/step
# Epoch 908/1000
# 3/3 - 0s - loss: 9.0078 - val_loss: 6.4480 - 53ms/epoch - 18ms/step
# Epoch 909/1000
# 3/3 - 0s - loss: 9.0040 - val_loss: 6.4426 - 52ms/epoch - 17ms/step
# Epoch 910/1000
# 3/3 - 0s - loss: 9.0032 - val_loss: 6.4350 - 48ms/epoch - 16ms/step
# Epoch 911/1000
# 3/3 - 0s - loss: 8.9997 - val_loss: 6.4308 - 50ms/epoch - 17ms/step
# Epoch 912/1000
# 3/3 - 0s - loss: 8.9962 - val_loss: 6.4296 - 52ms/epoch - 17ms/step
# Epoch 913/1000
# 3/3 - 0s - loss: 8.9935 - val_loss: 6.4250 - 50ms/epoch - 17ms/step
# Epoch 914/1000
# 3/3 - 0s - loss: 8.9900 - val_loss: 6.4256 - 28ms/epoch - 9ms/step
# Epoch 915/1000
# 3/3 - 0s - loss: 8.9854 - val_loss: 6.4244 - 92ms/epoch - 31ms/step
# Epoch 916/1000
# 3/3 - 0s - loss: 8.9815 - val_loss: 6.4213 - 63ms/epoch - 21ms/step
# Epoch 917/1000
# 3/3 - 0s - loss: 8.9775 - val_loss: 6.4185 - 53ms/epoch - 18ms/step
# Epoch 918/1000
# 3/3 - 0s - loss: 8.9762 - val_loss: 6.4153 - 55ms/epoch - 18ms/step
# Epoch 919/1000
# 3/3 - 0s - loss: 8.9729 - val_loss: 6.4121 - 67ms/epoch - 22ms/step
# Epoch 920/1000
# 3/3 - 0s - loss: 8.9689 - val_loss: 6.4103 - 60ms/epoch - 20ms/step
# Epoch 921/1000
# 3/3 - 0s - loss: 8.9655 - val_loss: 6.4079 - 64ms/epoch - 21ms/step
# Epoch 922/1000
# 3/3 - 0s - loss: 8.9622 - val_loss: 6.4075 - 59ms/epoch - 20ms/step
# Epoch 923/1000
# 3/3 - 0s - loss: 8.9599 - val_loss: 6.4066 - 54ms/epoch - 18ms/step
# Epoch 924/1000
# 3/3 - 0s - loss: 8.9562 - val_loss: 6.4026 - 56ms/epoch - 19ms/step
# Epoch 925/1000
# 3/3 - 0s - loss: 8.9542 - val_loss: 6.3996 - 63ms/epoch - 21ms/step
# Epoch 926/1000
# 3/3 - 0s - loss: 8.9504 - val_loss: 6.3977 - 59ms/epoch - 20ms/step
# Epoch 927/1000
# 3/3 - 0s - loss: 8.9473 - val_loss: 6.3944 - 47ms/epoch - 16ms/step
# Epoch 928/1000
# 3/3 - 0s - loss: 8.9458 - val_loss: 6.3916 - 51ms/epoch - 17ms/step
# Epoch 929/1000
# 3/3 - 0s - loss: 8.9420 - val_loss: 6.3904 - 47ms/epoch - 16ms/step
# Epoch 930/1000
# 3/3 - 0s - loss: 8.9394 - val_loss: 6.3865 - 52ms/epoch - 17ms/step
# Epoch 931/1000
# 3/3 - 0s - loss: 8.9362 - val_loss: 6.3838 - 47ms/epoch - 16ms/step
# Epoch 932/1000
# 3/3 - 0s - loss: 8.9333 - val_loss: 6.3828 - 53ms/epoch - 18ms/step
# Epoch 933/1000
# 3/3 - 0s - loss: 8.9309 - val_loss: 6.3802 - 45ms/epoch - 15ms/step
# Epoch 934/1000
# 3/3 - 0s - loss: 8.9285 - val_loss: 6.3785 - 52ms/epoch - 17ms/step
# Epoch 935/1000
# 3/3 - 0s - loss: 8.9252 - val_loss: 6.3730 - 50ms/epoch - 17ms/step
# Epoch 936/1000
# 3/3 - 0s - loss: 8.9226 - val_loss: 6.3690 - 47ms/epoch - 16ms/step
# Epoch 937/1000
# 3/3 - 0s - loss: 8.9204 - val_loss: 6.3669 - 53ms/epoch - 18ms/step
# Epoch 938/1000
# 3/3 - 0s - loss: 8.9179 - val_loss: 6.3618 - 50ms/epoch - 17ms/step
# Epoch 939/1000
# 3/3 - 0s - loss: 8.9160 - val_loss: 6.3582 - 51ms/epoch - 17ms/step
# Epoch 940/1000
# 3/3 - 0s - loss: 8.9140 - val_loss: 6.3550 - 47ms/epoch - 16ms/step
# Epoch 941/1000
# 3/3 - 0s - loss: 8.9129 - val_loss: 6.3520 - 69ms/epoch - 23ms/step
# Epoch 942/1000
# 3/3 - 0s - loss: 8.9093 - val_loss: 6.3492 - 50ms/epoch - 17ms/step
# Epoch 943/1000
# 3/3 - 0s - loss: 8.9066 - val_loss: 6.3477 - 98ms/epoch - 33ms/step
# Epoch 944/1000
# 3/3 - 0s - loss: 8.9043 - val_loss: 6.3461 - 48ms/epoch - 16ms/step
# Epoch 945/1000
# 3/3 - 0s - loss: 8.8990 - val_loss: 6.3440 - 50ms/epoch - 17ms/step
# Epoch 946/1000
# 3/3 - 0s - loss: 8.8983 - val_loss: 6.3464 - 31ms/epoch - 10ms/step
# Epoch 947/1000
# 3/3 - 0s - loss: 8.8943 - val_loss: 6.3451 - 29ms/epoch - 10ms/step
# Epoch 948/1000
# 3/3 - 0s - loss: 8.8946 - val_loss: 6.3425 - 52ms/epoch - 17ms/step
# Epoch 949/1000
# 3/3 - 0s - loss: 8.8878 - val_loss: 6.3389 - 55ms/epoch - 18ms/step
# Epoch 950/1000
# 3/3 - 0s - loss: 8.8860 - val_loss: 6.3344 - 55ms/epoch - 18ms/step
# Epoch 951/1000
# 3/3 - 0s - loss: 8.8840 - val_loss: 6.3348 - 33ms/epoch - 11ms/step
# Epoch 952/1000
# 3/3 - 0s - loss: 8.8806 - val_loss: 6.3297 - 64ms/epoch - 21ms/step
# Epoch 953/1000
# 3/3 - 0s - loss: 8.8774 - val_loss: 6.3281 - 61ms/epoch - 20ms/step
# Epoch 954/1000
# 3/3 - 0s - loss: 8.8754 - val_loss: 6.3253 - 62ms/epoch - 21ms/step
# Epoch 955/1000
# 3/3 - 0s - loss: 8.8742 - val_loss: 6.3267 - 42ms/epoch - 14ms/step
# Epoch 956/1000
# 3/3 - 0s - loss: 8.8713 - val_loss: 6.3263 - 35ms/epoch - 12ms/step
# Epoch 957/1000
# 3/3 - 0s - loss: 8.8679 - val_loss: 6.3210 - 60ms/epoch - 20ms/step
# Epoch 958/1000
# 3/3 - 0s - loss: 8.8652 - val_loss: 6.3224 - 39ms/epoch - 13ms/step
# Epoch 959/1000
# 3/3 - 0s - loss: 8.8625 - val_loss: 6.3207 - 58ms/epoch - 19ms/step
# Epoch 960/1000
# 3/3 - 0s - loss: 8.8599 - val_loss: 6.3177 - 65ms/epoch - 22ms/step
# Epoch 961/1000
# 3/3 - 0s - loss: 8.8576 - val_loss: 6.3171 - 60ms/epoch - 20ms/step
# Epoch 962/1000
# 3/3 - 0s - loss: 8.8554 - val_loss: 6.3153 - 71ms/epoch - 24ms/step
# Epoch 963/1000
# 3/3 - 0s - loss: 8.8531 - val_loss: 6.3143 - 50ms/epoch - 17ms/step
# Epoch 964/1000
# 3/3 - 0s - loss: 8.8513 - val_loss: 6.3098 - 51ms/epoch - 17ms/step
# Epoch 965/1000
# 3/3 - 0s - loss: 8.8496 - val_loss: 6.3064 - 59ms/epoch - 20ms/step
# Epoch 966/1000
# 3/3 - 0s - loss: 8.8474 - val_loss: 6.3027 - 50ms/epoch - 17ms/step
# Epoch 967/1000
# 3/3 - 0s - loss: 8.8442 - val_loss: 6.2998 - 51ms/epoch - 17ms/step
# Epoch 968/1000
# 3/3 - 0s - loss: 8.8414 - val_loss: 6.2975 - 55ms/epoch - 18ms/step
# Epoch 969/1000
# 3/3 - 0s - loss: 8.8388 - val_loss: 6.2952 - 57ms/epoch - 19ms/step
# Epoch 970/1000
# 3/3 - 0s - loss: 8.8368 - val_loss: 6.2924 - 59ms/epoch - 20ms/step
# Epoch 971/1000
# 3/3 - 0s - loss: 8.8368 - val_loss: 6.2919 - 60ms/epoch - 20ms/step
# Epoch 972/1000
# 3/3 - 0s - loss: 8.8319 - val_loss: 6.2899 - 63ms/epoch - 21ms/step
# Epoch 973/1000
# 3/3 - 0s - loss: 8.8307 - val_loss: 6.2854 - 95ms/epoch - 32ms/step
# Epoch 974/1000
# 3/3 - 0s - loss: 8.8295 - val_loss: 6.2890 - 31ms/epoch - 10ms/step
# Epoch 975/1000
# 3/3 - 0s - loss: 8.8259 - val_loss: 6.2888 - 28ms/epoch - 9ms/step
# Epoch 976/1000
# 3/3 - 0s - loss: 8.8241 - val_loss: 6.2873 - 32ms/epoch - 11ms/step
# Epoch 977/1000
# 3/3 - 0s - loss: 8.8222 - val_loss: 6.2871 - 28ms/epoch - 9ms/step
# Epoch 978/1000
# 3/3 - 0s - loss: 8.8201 - val_loss: 6.2854 - 30ms/epoch - 10ms/step
# Epoch 978: early stopping
# 3/3 [==============================] - 0s 2ms/step
# Score (RMSE): 2.5070741176605225

# %% [markdown]
# ### Next we vary the optimizer paramters (SGD), learning rate, batch size (32)

# %%
model = Sequential()
model.add(Dense(10, input_dim=x.shape[1], activation='relu'))
 
model.add(Dense(1, activation='relu'))

sgd = optimizers.SGD(learning_rate=0.0001, decay=1e-6, momentum=0.9, nesterov=True)   # much smaller lr
model.compile(loss='mean_squared_error', optimizer=sgd)

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
checkpointer = ModelCheckpoint(filepath="dnn/best_weights.keras", verbose=0, save_best_only=True) # save best model

# batch_size: Integer or None. Number of samples per gradient update. If unspecified, batch_size will default to 32.
model.fit(x_train,y_train,validation_data=(x_test,y_test), batch_size= 32, callbacks=[monitor,checkpointer],verbose=2,epochs=1000)
model.load_weights('dnn/best_weights.keras') # load weights from best model
# Predict and measure RMSE
pred = model.predict(x_test)
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Score (RMSE): {}".format(score))

# Plot the chart
chart_regression(pred.flatten(),y_test)
# Out:
# Epoch 1/1000
# 10/10 - 0s - loss: 617.8535 - val_loss: 586.9799 - 386ms/epoch - 39ms/step
# Epoch 2/1000
# 10/10 - 0s - loss: 614.9659 - val_loss: 581.4077 - 90ms/epoch - 9ms/step
# Epoch 3/1000
# 10/10 - 0s - loss: 605.0500 - val_loss: 565.9962 - 74ms/epoch - 7ms/step
# Epoch 4/1000
# 10/10 - 0s - loss: 580.3584 - val_loss: 530.1549 - 66ms/epoch - 7ms/step
# Epoch 5/1000
# 10/10 - 0s - loss: 531.4445 - val_loss: 463.4435 - 68ms/epoch - 7ms/step
# Epoch 6/1000
# 10/10 - 0s - loss: 439.3571 - val_loss: 349.1198 - 67ms/epoch - 7ms/step
# Epoch 7/1000
# 10/10 - 0s - loss: 297.3420 - val_loss: 196.5583 - 75ms/epoch - 8ms/step
# Epoch 8/1000
# 10/10 - 0s - loss: 148.2016 - val_loss: 92.5048 - 75ms/epoch - 7ms/step
# Epoch 9/1000
# 10/10 - 0s - loss: 82.5290 - val_loss: 75.7700 - 77ms/epoch - 8ms/step
# Epoch 10/1000
# 10/10 - 0s - loss: 72.7648 - val_loss: 69.1509 - 94ms/epoch - 9ms/step
# Epoch 11/1000
# 10/10 - 0s - loss: 61.9051 - val_loss: 57.0295 - 99ms/epoch - 10ms/step
# Epoch 12/1000
# 10/10 - 0s - loss: 51.4452 - val_loss: 46.9135 - 99ms/epoch - 10ms/step
# Epoch 13/1000
# 10/10 - 0s - loss: 42.3959 - val_loss: 37.9569 - 90ms/epoch - 9ms/step
# Epoch 14/1000
# 10/10 - 0s - loss: 34.0625 - val_loss: 29.1022 - 108ms/epoch - 11ms/step
# Epoch 15/1000
# 10/10 - 0s - loss: 26.4051 - val_loss: 21.1350 - 114ms/epoch - 11ms/step
# Epoch 16/1000
# 10/10 - 0s - loss: 19.9147 - val_loss: 14.9884 - 96ms/epoch - 10ms/step
# Epoch 17/1000
# 10/10 - 0s - loss: 14.9645 - val_loss: 11.0707 - 96ms/epoch - 10ms/step
# Epoch 18/1000
# 10/10 - 0s - loss: 12.1679 - val_loss: 9.0628 - 90ms/epoch - 9ms/step
# Epoch 19/1000
# 10/10 - 0s - loss: 10.9529 - val_loss: 8.1685 - 84ms/epoch - 8ms/step
# Epoch 20/1000
# 10/10 - 0s - loss: 10.4152 - val_loss: 7.8736 - 85ms/epoch - 8ms/step
# Epoch 21/1000
# 10/10 - 0s - loss: 10.2042 - val_loss: 7.5850 - 82ms/epoch - 8ms/step
# Epoch 22/1000
# 10/10 - 0s - loss: 9.9599 - val_loss: 7.3813 - 91ms/epoch - 9ms/step
# Epoch 23/1000
# 10/10 - 0s - loss: 9.8280 - val_loss: 7.2452 - 151ms/epoch - 15ms/step
# Epoch 24/1000
# 10/10 - 0s - loss: 9.6339 - val_loss: 7.0257 - 86ms/epoch - 9ms/step
# Epoch 25/1000
# 10/10 - 0s - loss: 9.4897 - val_loss: 6.8301 - 83ms/epoch - 8ms/step
# Epoch 26/1000
# 10/10 - 0s - loss: 9.3774 - val_loss: 6.7205 - 75ms/epoch - 7ms/step
# Epoch 27/1000
# 10/10 - 0s - loss: 9.2597 - val_loss: 6.6108 - 72ms/epoch - 7ms/step
# Epoch 28/1000
# 10/10 - 0s - loss: 9.1639 - val_loss: 6.5634 - 76ms/epoch - 8ms/step
# Epoch 29/1000
# 10/10 - 0s - loss: 9.0636 - val_loss: 6.4615 - 81ms/epoch - 8ms/step
# Epoch 30/1000
# 10/10 - 0s - loss: 9.0133 - val_loss: 6.3225 - 70ms/epoch - 7ms/step
# Epoch 31/1000
# 10/10 - 0s - loss: 8.8959 - val_loss: 6.3089 - 81ms/epoch - 8ms/step
# Epoch 32/1000
# 10/10 - 0s - loss: 8.8288 - val_loss: 6.2283 - 82ms/epoch - 8ms/step
# Epoch 33/1000
# 10/10 - 0s - loss: 8.7666 - val_loss: 6.1585 - 95ms/epoch - 9ms/step
# Epoch 34/1000
# 10/10 - 0s - loss: 8.7163 - val_loss: 6.1351 - 75ms/epoch - 8ms/step
# Epoch 35/1000
# 10/10 - 0s - loss: 8.6592 - val_loss: 6.0754 - 65ms/epoch - 7ms/step
# Epoch 36/1000
# 10/10 - 0s - loss: 8.6323 - val_loss: 5.9842 - 69ms/epoch - 7ms/step
# Epoch 37/1000
# 10/10 - 0s - loss: 8.5879 - val_loss: 6.0120 - 81ms/epoch - 8ms/step
# Epoch 38/1000
# 10/10 - 0s - loss: 8.5175 - val_loss: 5.9446 - 80ms/epoch - 8ms/step
# Epoch 39/1000
# 10/10 - 0s - loss: 8.4816 - val_loss: 5.8878 - 79ms/epoch - 8ms/step
# Epoch 40/1000
# 10/10 - 0s - loss: 8.4584 - val_loss: 5.9242 - 64ms/epoch - 6ms/step
# Epoch 41/1000
# 10/10 - 0s - loss: 8.4293 - val_loss: 5.8362 - 91ms/epoch - 9ms/step
# Epoch 42/1000
# 10/10 - 0s - loss: 8.3760 - val_loss: 5.8185 - 77ms/epoch - 8ms/step
# Epoch 43/1000
# 10/10 - 0s - loss: 8.3460 - val_loss: 5.8128 - 63ms/epoch - 6ms/step
# Epoch 44/1000
# 10/10 - 0s - loss: 8.3076 - val_loss: 5.7933 - 80ms/epoch - 8ms/step
# Epoch 45/1000
# 10/10 - 0s - loss: 8.2889 - val_loss: 5.7533 - 89ms/epoch - 9ms/step
# Epoch 46/1000
# 10/10 - 0s - loss: 8.2545 - val_loss: 5.7396 - 85ms/epoch - 8ms/step
# Epoch 47/1000
# 10/10 - 0s - loss: 8.2396 - val_loss: 5.7256 - 90ms/epoch - 9ms/step
# Epoch 48/1000
# 10/10 - 0s - loss: 8.2168 - val_loss: 5.7189 - 89ms/epoch - 9ms/step
# Epoch 49/1000
# 10/10 - 0s - loss: 8.2026 - val_loss: 5.6647 - 89ms/epoch - 9ms/step
# Epoch 50/1000
# 10/10 - 0s - loss: 8.2012 - val_loss: 5.6792 - 71ms/epoch - 7ms/step
# Epoch 51/1000
# 10/10 - 0s - loss: 8.1593 - val_loss: 5.6469 - 83ms/epoch - 8ms/step
# Epoch 52/1000
# 10/10 - 0s - loss: 8.1468 - val_loss: 5.6595 - 59ms/epoch - 6ms/step
# Epoch 53/1000
# 10/10 - 0s - loss: 8.1081 - val_loss: 5.6567 - 53ms/epoch - 5ms/step
# Epoch 54/1000
# 10/10 - 0s - loss: 8.1242 - val_loss: 5.5796 - 117ms/epoch - 12ms/step
# Epoch 55/1000
# 10/10 - 0s - loss: 8.0924 - val_loss: 5.6135 - 68ms/epoch - 7ms/step
# Epoch 56/1000
# 10/10 - 0s - loss: 8.0794 - val_loss: 5.6015 - 38ms/epoch - 4ms/step
# Epoch 57/1000
# 10/10 - 0s - loss: 8.0550 - val_loss: 5.5943 - 53ms/epoch - 5ms/step
# Epoch 58/1000
# 10/10 - 0s - loss: 8.0488 - val_loss: 5.5697 - 76ms/epoch - 8ms/step
# Epoch 59/1000
# 10/10 - 0s - loss: 8.0058 - val_loss: 5.5333 - 95ms/epoch - 10ms/step
# Epoch 60/1000
# 10/10 - 0s - loss: 8.0126 - val_loss: 5.5012 - 86ms/epoch - 9ms/step
# Epoch 61/1000
# 10/10 - 0s - loss: 7.9998 - val_loss: 5.5209 - 64ms/epoch - 6ms/step
# Epoch 62/1000
# 10/10 - 0s - loss: 7.9787 - val_loss: 5.5329 - 61ms/epoch - 6ms/step
# Epoch 63/1000
# 10/10 - 0s - loss: 7.9760 - val_loss: 5.5184 - 59ms/epoch - 6ms/step
# Epoch 64/1000
# 10/10 - 0s - loss: 7.9731 - val_loss: 5.5571 - 58ms/epoch - 6ms/step
# Epoch 65/1000
# 10/10 - 0s - loss: 7.9473 - val_loss: 5.5435 - 50ms/epoch - 5ms/step
# Epoch 65: early stopping
# 3/3 [==============================] - 0s 3ms/step
# Score (RMSE): 2.3454740047454834

# %% [markdown]
# ### Dropout Layer  (A dedicated layer for regularization)
#
# A dropout layer can be added between any two hidden layers to reduce overfitting.
#
# ***To create a dropout layer, specify dropout probability.***  The dropout probability indicates the likelihood of a neuron dropping out for every batch during training. Typically this value is 0.1 to 0.5.
#
# ***Actually, a certain percentage of neurons will be masked during each training iteration.  All neurons return after training is complete.***
#
# Let's add some dropout

# %%
from tensorflow.keras.layers import Dense, Activation, Dropout


model = Sequential()
model.add(Dense(100, input_dim=x.shape[1], activation='relu')) #changed to 100

model.add(Dropout(0.1)) 

model.add(Dense(1, activation='relu'))


sgd = optimizers.SGD(learning_rate=0.0001, decay=1e-6, momentum=0.9, nesterov=True)   # much smaller lr
model.compile(loss='mean_squared_error', optimizer=sgd)


monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
checkpointer = ModelCheckpoint(filepath="dnn/best_weights.hdf5", verbose=0, save_best_only=True) # save best model

# batch_size: Integer or None. Number of samples per gradient update. If unspecified, batch_size will default to 32.
model.fit(x_train,y_train,validation_data=(x_test,y_test), batch_size= 32, callbacks=[monitor,checkpointer],verbose=2,epochs=1000)
model.load_weights('dnn/best_weights.hdf5') # load weights from best model

# Predict and measure RMSE
pred = model.predict(x_test)
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Score (RMSE): {}".format(score))

# Plot the chart
chart_regression(pred.flatten(),y_test)
# Out:
# Epoch 1/1000
# 10/10 - 1s - loss: 618.3478 - val_loss: 585.5895 - 616ms/epoch - 62ms/step
# Epoch 2/1000
# 10/10 - 0s - loss: 602.7363 - val_loss: 542.9321 - 83ms/epoch - 8ms/step
# Epoch 3/1000
# 10/10 - 0s - loss: 532.2507 - val_loss: 449.1450 - 73ms/epoch - 7ms/step
# Epoch 4/1000
# 10/10 - 0s - loss: 415.1703 - val_loss: 308.0575 - 67ms/epoch - 7ms/step
# Epoch 5/1000
# 10/10 - 0s - loss: 246.8506 - val_loss: 141.2903 - 67ms/epoch - 7ms/step
# Epoch 6/1000
# 10/10 - 0s - loss: 94.0908 - val_loss: 43.3354 - 83ms/epoch - 8ms/step
# Epoch 7/1000
# 10/10 - 0s - loss: 37.9951 - val_loss: 32.0935 - 67ms/epoch - 7ms/step
# Epoch 8/1000
# 10/10 - 0s - loss: 30.0393 - val_loss: 25.0526 - 64ms/epoch - 6ms/step
# Epoch 9/1000
# 10/10 - 0s - loss: 23.0523 - val_loss: 18.2438 - 75ms/epoch - 8ms/step
# Epoch 10/1000
# 10/10 - 0s - loss: 22.0720 - val_loss: 16.2293 - 67ms/epoch - 7ms/step
# Epoch 11/1000
# 10/10 - 0s - loss: 19.8206 - val_loss: 15.0086 - 64ms/epoch - 6ms/step
# Epoch 12/1000
# 10/10 - 0s - loss: 16.9379 - val_loss: 13.9534 - 77ms/epoch - 8ms/step
# Epoch 13/1000
# 10/10 - 0s - loss: 17.1987 - val_loss: 13.0419 - 92ms/epoch - 9ms/step
# Epoch 14/1000
# 10/10 - 0s - loss: 16.5733 - val_loss: 12.2366 - 85ms/epoch - 9ms/step
# Epoch 15/1000
# 10/10 - 0s - loss: 16.6833 - val_loss: 11.4998 - 73ms/epoch - 7ms/step
# Epoch 16/1000
# 10/10 - 0s - loss: 15.6701 - val_loss: 10.9285 - 72ms/epoch - 7ms/step
# Epoch 17/1000
# 10/10 - 0s - loss: 14.8130 - val_loss: 10.3663 - 65ms/epoch - 7ms/step
# Epoch 18/1000
# 10/10 - 0s - loss: 16.6798 - val_loss: 9.9611 - 66ms/epoch - 7ms/step
# Epoch 19/1000
# 10/10 - 0s - loss: 13.8929 - val_loss: 9.5909 - 74ms/epoch - 7ms/step
# Epoch 20/1000
# 10/10 - 0s - loss: 14.4045 - val_loss: 9.2291 - 84ms/epoch - 8ms/step
# Epoch 21/1000
# 10/10 - 0s - loss: 14.0613 - val_loss: 8.7864 - 77ms/epoch - 8ms/step
# Epoch 22/1000
# 10/10 - 0s - loss: 13.4846 - val_loss: 8.4004 - 67ms/epoch - 7ms/step
# Epoch 23/1000
# 10/10 - 0s - loss: 13.2695 - val_loss: 8.1295 - 75ms/epoch - 8ms/step
# Epoch 24/1000
# 10/10 - 0s - loss: 13.2897 - val_loss: 7.8998 - 77ms/epoch - 8ms/step
# Epoch 25/1000
# 10/10 - 0s - loss: 13.5083 - val_loss: 7.7112 - 74ms/epoch - 7ms/step
# Epoch 26/1000
# 10/10 - 0s - loss: 11.8896 - val_loss: 7.4847 - 76ms/epoch - 8ms/step
# Epoch 27/1000
# 10/10 - 0s - loss: 11.9323 - val_loss: 7.2660 - 65ms/epoch - 6ms/step
# Epoch 28/1000
# 10/10 - 0s - loss: 13.2842 - val_loss: 7.1020 - 67ms/epoch - 7ms/step
# Epoch 29/1000
# 10/10 - 0s - loss: 12.2236 - val_loss: 6.9594 - 66ms/epoch - 7ms/step
# Epoch 30/1000
# 10/10 - 0s - loss: 12.9068 - val_loss: 6.9894 - 60ms/epoch - 6ms/step
# Epoch 31/1000
# 10/10 - 0s - loss: 11.9525 - val_loss: 6.8335 - 75ms/epoch - 7ms/step
# Epoch 32/1000
# 10/10 - 0s - loss: 13.4289 - val_loss: 6.6718 - 73ms/epoch - 7ms/step
# Epoch 33/1000
# 10/10 - 0s - loss: 12.0139 - val_loss: 6.5582 - 74ms/epoch - 7ms/step
# Epoch 34/1000
# 10/10 - 0s - loss: 10.5147 - val_loss: 6.4610 - 73ms/epoch - 7ms/step
# Epoch 35/1000
# 10/10 - 0s - loss: 11.4609 - val_loss: 6.3430 - 84ms/epoch - 8ms/step
# Epoch 36/1000
# 10/10 - 0s - loss: 11.0028 - val_loss: 6.2494 - 83ms/epoch - 8ms/step
# Epoch 37/1000
# 10/10 - 0s - loss: 12.1624 - val_loss: 6.1512 - 82ms/epoch - 8ms/step
# Epoch 38/1000
# 10/10 - 0s - loss: 11.5064 - val_loss: 6.1482 - 83ms/epoch - 8ms/step
# Epoch 39/1000
# 10/10 - 0s - loss: 11.1653 - val_loss: 6.0972 - 72ms/epoch - 7ms/step
# Epoch 40/1000
# 10/10 - 0s - loss: 10.6435 - val_loss: 6.0702 - 91ms/epoch - 9ms/step
# Epoch 41/1000
# 10/10 - 0s - loss: 12.5282 - val_loss: 6.0333 - 75ms/epoch - 8ms/step
# Epoch 42/1000
# 10/10 - 0s - loss: 11.9106 - val_loss: 5.9841 - 84ms/epoch - 8ms/step
# Epoch 43/1000
# 10/10 - 0s - loss: 11.0549 - val_loss: 5.9222 - 67ms/epoch - 7ms/step
# Epoch 44/1000
# 10/10 - 0s - loss: 11.5472 - val_loss: 5.8904 - 75ms/epoch - 8ms/step
# Epoch 45/1000
# 10/10 - 0s - loss: 12.4051 - val_loss: 5.8809 - 82ms/epoch - 8ms/step
# Epoch 46/1000
# 10/10 - 0s - loss: 10.9325 - val_loss: 5.8657 - 67ms/epoch - 7ms/step
# Epoch 47/1000
# 10/10 - 0s - loss: 11.5083 - val_loss: 5.8519 - 100ms/epoch - 10ms/step
# Epoch 48/1000
# 10/10 - 0s - loss: 12.5400 - val_loss: 5.8232 - 75ms/epoch - 7ms/step
# Epoch 49/1000
# 10/10 - 0s - loss: 11.4358 - val_loss: 5.8649 - 50ms/epoch - 5ms/step
# Epoch 50/1000
# 10/10 - 0s - loss: 11.2811 - val_loss: 5.8054 - 67ms/epoch - 7ms/step
# Epoch 51/1000
# 10/10 - 0s - loss: 10.9705 - val_loss: 5.7557 - 92ms/epoch - 9ms/step
# Epoch 52/1000
# 10/10 - 0s - loss: 10.9204 - val_loss: 5.7174 - 135ms/epoch - 13ms/step
# Epoch 53/1000
# 10/10 - 0s - loss: 10.4134 - val_loss: 5.7160 - 65ms/epoch - 6ms/step
# Epoch 54/1000
# 10/10 - 0s - loss: 11.0557 - val_loss: 5.6959 - 58ms/epoch - 6ms/step
# Epoch 55/1000
# 10/10 - 0s - loss: 10.1504 - val_loss: 5.6638 - 73ms/epoch - 7ms/step
# Epoch 56/1000
# 10/10 - 0s - loss: 11.3830 - val_loss: 5.6690 - 66ms/epoch - 7ms/step
# Epoch 57/1000
# 10/10 - 0s - loss: 9.3566 - val_loss: 5.6756 - 64ms/epoch - 6ms/step
# Epoch 58/1000
# 10/10 - 0s - loss: 10.0264 - val_loss: 5.7082 - 75ms/epoch - 7ms/step
# Epoch 59/1000
# 10/10 - 0s - loss: 10.7397 - val_loss: 5.6781 - 65ms/epoch - 6ms/step
# Epoch 60/1000
# 10/10 - 0s - loss: 11.4389 - val_loss: 5.6518 - 92ms/epoch - 9ms/step
# Epoch 61/1000
# 10/10 - 0s - loss: 10.7739 - val_loss: 5.6061 - 85ms/epoch - 8ms/step
# Epoch 62/1000
# 10/10 - 0s - loss: 10.1254 - val_loss: 5.5755 - 76ms/epoch - 8ms/step
# Epoch 63/1000
# 10/10 - 0s - loss: 9.9169 - val_loss: 5.5822 - 50ms/epoch - 5ms/step
# Epoch 64/1000
# 10/10 - 0s - loss: 9.7526 - val_loss: 5.6410 - 61ms/epoch - 6ms/step
# Epoch 65/1000
# 10/10 - 0s - loss: 10.4027 - val_loss: 5.5375 - 82ms/epoch - 8ms/step
# Epoch 66/1000
# 10/10 - 0s - loss: 10.4202 - val_loss: 5.4711 - 89ms/epoch - 9ms/step
# Epoch 67/1000
# 10/10 - 0s - loss: 10.5798 - val_loss: 5.4279 - 88ms/epoch - 9ms/step
# Epoch 68/1000
# 10/10 - 0s - loss: 11.1100 - val_loss: 5.4291 - 51ms/epoch - 5ms/step
# Epoch 69/1000
# 10/10 - 0s - loss: 10.2043 - val_loss: 5.4368 - 51ms/epoch - 5ms/step
# Epoch 70/1000
# 10/10 - 0s - loss: 9.6323 - val_loss: 5.5357 - 55ms/epoch - 6ms/step
# Epoch 71/1000
# 10/10 - 0s - loss: 11.2390 - val_loss: 5.5074 - 52ms/epoch - 5ms/step
# Epoch 72/1000
# 10/10 - 0s - loss: 9.9013 - val_loss: 5.4762 - 56ms/epoch - 6ms/step
# Epoch 72: early stopping
# 3/3 [==============================] - 0s 0s/step
# Score (RMSE): 2.3297836780548096

# %% [markdown]
# ### References:
#
# * [Google Colab](https://colab.research.google.com/) - Free web based platform that includes Python, Juypter Notebooks, and TensorFlow with free GPU support.  No setup needed.
# * [IBM Cognitive Class Labs](https://www.datascientistworkbench.com) - Free web based platform that includes Python, Juypter Notebooks, and TensorFlow.  No setup needed.
# * [Python Anaconda](https://www.continuum.io/downloads) - Python distribution that includes many data science packages, such as Numpy, Scipy, Scikit-Learn, Pandas, and much more.
# * [TensorFlow](https://www.tensorflow.org/) - Google's mathematics package for deep learning.
# * [Kaggle](https://www.kaggle.com/) - Competitive data science.  Good source of sample data.
# * T81-558: Applications of Deep Neural Networks. Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/)
